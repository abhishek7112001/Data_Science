# %% [markdown]
# ## Types of Companies

# %%
Product Based >> Amazon, Zomato 
Service Based >> Infosys, Cognizant

# %%
     Profile         Designation
  Data Science     Data Scientist
                   ML Engineer
                   Data Engineer
                   Data Analyst
                   Python Developer
                   Decision Scientist
                   Software Engineer

# %%
Data Scientist:
    1. Must be a Good Story teller
    2. Must asked too many business related queries/questions

# %% [markdown]
# ## Why Project actually exist

# %%
Why project actually exist:
    Revenue Generation(Maximisation)
    Revenue Loss (Optimization)
    Manpower management
    Time management
    Process Management
    Automation

# %%
                  pos      neg
               non-def     def
non-def  pos      TP       FP
def      neg      FN       TN


Precision >> def been predicted as non defaulter >> loan will be given to wrong person >> Revenue Loss

Recall >> non def been predicted as defaulter >> loan should have been given to non def >> Revenue Generation Stopped

Revenue Generation(Maximisation):
    Recall
    
Revenue Loss (Optimization):
    Precision

# %%
How do we get Project:
    Tech Exhibitions
    Marketing Campaigns
    Word of Mouth
    
    POC(Proof of Concept): # Test Drive
        Duration:
            Paid POC:
                3-4 weeks
                6-8 Weeks

            Non Paid POC:
                3-4 Days
                1 week 
                2 week
                
    Timeline for the project >> Higher Authority, Solution heads, Delivery Heads, CTO, CFO, Sale & Marketing Team
    Process Timeline >> Manager, Tech Lead, Project Manager

# %% [markdown]
# ### Virtual Machine (VDE >> Virtual Desktop Environment)

# %%
Local System:
    A system(Laptop/Computer) available with you phisically, and you work on it.
    
Virtual System:
    A system where you can log in online and have the same interface as local system.

# %% [markdown]
# ## Project Kickoff

# %%
Onboarding of Project/Project Kickoff:
    PPT/Deck, Approach, Problem statement, requirements, tools, duration, workforce/manpower >> Client Meet
    System COnfiguration/Setup
    Project Assign
    Main Work
    Project Management Tools:
        JIRA, ASANA, ZOHO, Trello, Pivotal Tracker
        
Client Side ID (Suvarna.kakde@citibank.com)
Suvarna.kakde
Suvarnakakde
Suvarnakakde1
Suvarna.kakde1
Suvarna1kakde

# %%
Problem Statement/ Business Problem/ Business Requirements/Business Scenario/Use Case:
    
Pre-requisites:
    
Hypothesis Generation:
    
What are the approach: (Multiple Approaches)
    Without ML
    Regression
    Classification
    NLP
    DL
    Time Series 
    Rule Based Engine
    SMA(Simple Moving Average)
    Clustering(Segmentation)
    Computer vision
    Chatbot >> RASA, Dialog

# %%
Data Requirements:
    What kind of features we need ?
    We require Data to perform Ops
    Loan:
        1. Demographic (Gender, Age, Income, Nationality, Occupation, Familty Details)
        2. Transaction (Credit, Debit, Type/category, Dates)
        3. Personal Accounts (Type of accnt, CIBIL, Accnt opening, Age of accnt)
        4. Loan history (Last loan, premium, installemts, default, ontime)
        5. Product holding

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## How do u recieve ur Data

# %%
DB/DW : DataBase/DataWareHouse >> Client
    
    1. Client DB (SQL Server)
    akash.gautam@hdfclife.co.in (Some optional credentials could be there)
    Virtaul Server (VDE >> Virtual Desktop Environment) >> Accoprs, VMWare, Citrix
    login >> servers
    Limitations >> No internet, no copying, Only one drive >> C-Drive
    Safe Environment
    
    2. Data Engineer (DB) >> mail
    3. Cloud S3 Bucket (AWS) >> Fetch >> Sagemaker >> Scripting
    4. DataBricks >> DBFS
    5. Third Party API
    6. Web Scraping/Data Extraction
    7. Kaggle, UCI repo

# %%
Project Duration:
    1 Week (Pre-Trained Models)
    1 Month
    2 months
    3-5 Months
    6-8 Months
    More than 6 or 8 Months >> Maintenance/Developement/CI CD(Pipeline) >> Docker, Jenkins, Snowflake, MLOps,MLflow, Kafka

# %%
How is the work assigned to u ? Project Management Tools:
    JIRA, Asana, Zoho, Trello, Pivotal Tracker, BaseCamp

# %% [markdown]
# ## Project Management Tools

# %%
JIRA, Trello, PivotalTracker, ZOHO, ASANA

JIRA:
    
    epic:
        Plan with Team Lead and manager
        2 months plan(8 weeks)
        EDA >> Week 1-2
        Feature Engg >> week 2
        Model Building  >> week 3
        Model Optimisation >> week 4-5
        Model Evaluation >> week 5
        DashBoard >> week 6
        
Sprint >> 2 Weeks in service based Companies
          1 Week in Product Based Companies

    Sprint 1(EDA):
        Story with full discription
        story1: Data Gathering(Database)
        story2: EDA(for features)
            
    Sprint 2 (Feature Engg):
        story1: EDA
        story2: Preprocessing
                Feature Engg
                
Issues: (from developers)
    Scaling with Normalization
    
Report will generate after completion of epic

Daily Stand up: (With manager) 30 to 60 min
    Daily updates (yesterdays tasks and todays tasks)
    Issues
      
TL >> Team Lead
PM >> Project Manager
RM >> Reporting Manager
HRM >> HR Manager
VP >> Vice President

# %%
How do u communicate within organization?:
    Teams, skype, hangouts(Google Chats), Slack, Outlook, Webex, Zoom

# %%
Daily Standup Call: Daily Update
    Eve
    Morning(1st half)
    Afternoon(2nd half)
    
    Team:
        you
        senior/tech lead
        jr/intern
        project manager
        power bi
        Data Engineer
        Manager
        
Client Meet:
    Once/Twice a week
    Once in 2 weeks
    once in a month
    
    UK (-5hrs from IST)
    US (-13.30 hrs from IST)

# %%
Cloud Services:
    DataBricks: Azure(Microsoft)
        Cloud tool for scripting adn Data Storage
        PySpark >> .topandas()
        DBFS >> DataBricks File System
        HDFS >> Hadoop DataBase File System
        
    Sagemaker: AWS
        S3 Bucket
        
Script Storage/Sharing:
    GitHub
    GitLab
    BitBucket

# %%
Access for system:
    Anydesk

# %%
How Frequently ur data was updated:
    Daily, weekly, 15 days, monthly
    
    today : 22-03-23
        EDA to finish on 21-04-23 >> Use data for EDA till 31st Jan
        Model >> Data till 28th Feb >> 1 st March to end of April >> Validation
        
    Rows will get added
    Columns will get added/will be removed

# %%
What was your role in Client Meeting?:
    
Who was there in your team: (4 - 8)
    Data Scientist/ML Engineer(2-4......6)
    Data Engineer(1,2)
    Business Analyst/Consultant/BI Engg
    Project Manager
    API Developer
    HTML/CSS
    Power BI/Tableau
    Manager
    
    Front End
    DB
    Backend
    FSD
    NodeJS,react, angular
    Web Development

# %%
Evaluation Metric:
    Regression:
        MAPE
        RMSPE
        R2 Squared
        A-R2 Squared
        MSPE
        
    Classification:
        Accuracy
        Precision
        Recall
        F1-Score
        AUC-ROC 
        Weighted avg
        Macro Avg
        
                  pos      neg
               non-def     def
non-def  pos      TP       FP
def      neg      FN       TN


Precision >> def been predicted as non defaulter >> loan will be given to wrong person >> Revenue Loss

Recall >> non def been predicted as defaulter >> loan should have been given to non def >> Revenue Generation Stopped

Revenue Generation(Maximisation):
    Recall
    
Revenue Loss (Optimization):
    Precision

# %%
Deploy:
    Online:
        AWS
        GCP
        Azure
        
    Offline:
        Predicted output in table format >> save it in excel/csv/JSON
        Fetch it on SQL Server
        (OverSpeed Gun, Traffic Signal)

# %%
Project Shifting:
    KT (Knowledge transfer) >> Handover
    Record:
        Windows + Alt + R
        Windows + G
        
    Snippet Tool:
        Win + Shift + S >> Screenshot for PPT
        
Company Laptop:
    There is ID & Password for installing any software
    
For any Queries:
    Generate Tickets:
        Company Portal:
            SpineHRMS, ZOHO, servicenow, drawinbox, peopledesk

# %%
1) Confidence 
2) Presence of Mind
3) Storyline

# %% [markdown]
# ### Resume

# %%
Resume:
    Objective/Profile Summary >> 2-4 sentence , Adjective, designation& work exp, Tech&soft skills, Domain, clients relation
    Professional Summary >> (Bullet Points) 4-10 Sentence > Competencies (Tech & Soft), Roles & Responisibilities
    Proper pointwise Description >> Work exp, education, profile
    Projects:
        Best Project Must on Top >> 1
        POC as Mini Project >> 3 to 2.5 yrs exp  
        Project Description:
            if common project name >> Spinbot
            Project Name, Domain
            Problem Statements, Scope of the Project, Approach for the project, 
            Solution (in terms of increment, decreament in percentage)
    Work Exp:
        only client Company(Speak about payroll comp only if they ask perticularly)
        Client Manager(Resume Company) name >> We cannot Share
    Tech Skills:
        Python, ML, DL, NLP,AWS, Flask, SQL, Data Science, Time Series, Data Analysis, Data Visualization,
        Predictive Modelling, Statistical Modelling, Web Scraping, Model Development, EDA, CLuster Analysis, Customer 
        Segmentation, DSA, Analytical problem solving, Regression, CLassification, OCR, Hypothesis Testing, Pattern 
        recognition, Qualitative & Quantitative Analysis, Advance Excel, Data Modelling, Azure DataBricks, Neural 
        Networks, OOPS

    Soft Skills:
        Written & Verbal Communication, Oganised, Interpersonal Skills, Teamwork, Presentation Skills, Punctual

    Libraries:
        OS, glob, re, pytesseract, pdf2image, Datetime, Numpy, Pandas, Scikit-Learn, Imblearn, Tensorflow, Keras, 
        NLTK, OpenCV, Statsmodels, Scipy, Fbprophet, Matplotlib, Seaborn, Plotly, Autoviz, Sweetviz, pandas profiling,
        functools, shutil, Flask, MlXtend

    Tools:
        Advance Excel, Git, AWS, Conda, Jupyter Notebook, VSCode, Postman, Azure DataBricks, AWS Sagemaker, S3, Google collab

    Personal Details:
        DOB, Gender, Address, City, Marital Status
    
    Awards & Achivements:
        Patent, Gold Medalist, Great achievement

    Education:
        (Mech , civil, electical) Do not mention it
        1. Highest Degree (if good marks then show it)
        2. Diploma 

    Remove Declaration:

    Bullet Points:
        IF Multiple then sub points & main points must have diff font size
    Spacing/Alignment:
    Justification >> ctrl + J

    No Extra Spaces should be there:
        if 1 Page resume must be till the end of page
        if 2 page resume must be till the end of page

# %% [markdown]
# ### Naukri Profile

# %%
Naukri Profile:
    Must complete 100 % of Profile.
    Photo >> Descent, Professional, in Plain Shirt
    Location >> No Pune, Do not say i want only remote
    
    If Recruiter search you:
        1. Skills
        2. Location
        3. Designation
        
        they can see:
            ADD all necessary skills
            1. Designation, Name, Company, Location
            2. Skills
            3. Resume headline
        
    Continous Updatation of profile:
        Every 0.5/1 hrs refresh >> Add something or remove something
    
    Resume Headline:
        2-4 sentence , Adjective, designation& work exp, Tech&soft skills, Domain, clients relation
        
    Key Skills:
        Python, ML, DL, NLP,AWS, Flask, SQL, Data Science, Time Series, Data Analysis, Data Visualization,
        Predictive Modelling, Statistical Modelling, Web Scraping, Model Development, EDA, CLuster Analysis, Customer 
        Segmentation, DSA, Analytical problem solving, Regression, CLassification, OCR, Hypothesis Testing, Pattern 
        recognition, Qualitative & Quantitative Analysis, Advance Excel, Data Modelling, Azure DataBricks, Neural 
        Networks, OOPS
    
    Employement:
        Job Profile >> 8 to 12 Sentences which shows what you were doing in your organization
        skills >> top 5 skills
        
    Education:
        ME/MSC/MCS/MCA , BE/BSC/BCA, Diploma
        
    IT Skills:
        Main Techs, Libraries, Fill Everything which you can (10 options)
        multiple in 1 box. [Python, OOPs, Web Scraping]
        
    Profile Summary:
        6-12 Sentence > Competencies (Tech & Soft), Roles & Responisibilities

# %% [markdown]
# ### Cover Letter

# %%
To >> hr@company.com >> Hr mail ID
Subject >> Resume for Data Scientist position(Raja Bahadur)

Hello Nikita,
    I am Raja Bahadur, Who r u? What R u? where do u work? location. 
    Skills (tech or non tech) , Proficient, competemncies, Domain
    why are you looking for change.
    
    PFA resume for your reference. Looking forward to here from you. 


thanks & regards,
Raja Bahadur
Mobile No. - +91 9977884455
Email ID. - rajabahadur@gmail.com

Attach Resume

# %%
Create Multiple Profile: Also on different JOb Portal (Naukri, Indeed, ApnaJOb, Monster)
    
    Create min 2 and max 3 Naukri profiles:
    2 mobile numbers, 2 Email IDs
    
    Remove Pune from 1st preference
    
    Profile 1:
        Bangalore
        Mumbai
        Chennai
        Pune
        
    Profile 2:
        Delhi
        Ahemdabad
        Kolkata
        Hyderabad
        
    Company:
        1 company >> worked on different locations for client(multiple)
        2 Company >> Worked for 2 clients , ready to relocate to any sites

# %%
Call from jr. HR/consultant >> Do not say no & No Sir/Mam:
    Note down who called u:
        1. name of HR, number
        2. Company & Location
        3. Role
        4. Interview Schedule
        5. 1st inteview result
    
    1. are you looking for job change?
    2. where are you based out?
    3. Current CTC
    4. Expected CTC
    5. SKills?
    6. Short intro
    7. Why are you looking for a change
    8. what is your notice period
    9. are you serving/ what is your LWD(Last Working Day) >> Notice period 
    10. Ask for JD(Job Description)
    
    Visit Website look what kind of work they are doing, domain, tools, company details, CEO, Estiblished
    
Pre-Assessment Test on Coding:
    Coding test
    Assignment on Use Case
    General Awareness
    
1st round:(2 to 5 yrs)
    Python coding
    Stats
    ML
    DL/NLP/TSA
    Project (8 - 12 min)
    
    Golden Question:
    Do you have any question?
    
    Write a thank note to HR

2nd round: (manager 4 & more yrs)
    project approach
    Genuinity of Candidate
    Use Case/Problem Statement >> Analysis
    Write a thank note to HR
    
We require Documents:
    Check firmly read, check twice
    
3rd HR: HR Manager
    Intro
    Background
    Salary Discussion
    
Recieved offer letter:
    Thank note on offer mail
    Resign from current company
    Screenshot of Resignation acceptance

# %%
Interview Dynamics:
    Introduction:(30 - 60 sec)
        Who are u ? name
        what r u? designation/company/exp/location
        Whhat skills do u have? domain?
        roles & responsibilities ? Client interaction ?
        Why r u looking for a change?
        
    Plan your Interview:
        Money Heist
        
    Politely ask for clarity

# %%
1. MOM (Minutes of Meetings):  (Fireflies.ai/Otter) >> Transcripts
    Points that were discussed in Meeting
    
2. White Paper:
    Approaches been covered throughout the tenure of the project
    
3. Creation of Target Feature

4. Googling in company

5. Real Time Accuracy

6. Bookmarks on screen while attending interviews:
    Only things which we are planning on improving:
        Medium, towardsdatascience, >> BorutaPy, MCC
        
7. Use Spectacle

8. KPI for Project

9. Description of Features(Data Defination)

10. Glassdoor:
    
11. Research about the company which you'll attend interview for.

12. Introvert after joining

13. Excel, read about data, Think like a data scientist, Business

14. Resume:
    1. Adjectives
    2. ATS >> Appln Tracking System >> HR >> Words use
    3. Bullet points font(large) & sub points font diff( small)
    4. alignment/spacing
    5. Tech skills
    6. Project Description:
        Problem Statement, Scope of the project, Approach of the project, Solution (Stas, %)
    7. Cover Letter:
        Subject: Job Application for ML Engg >> Name
