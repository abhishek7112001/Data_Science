# %%
import pandas as pd
import numpy as np
import se

# %%
df = pd.read_excel("Datasheets_Case Study_Research Analyst_ETG_Pulses.xlsx",sheet_name = 'Weather Data', skiprows=1)

# %%
df.head()
# Out:
#             Unnamed: 0 Unnamed: 1       Unnamed: 2 Unnamed: 3 District 1  \
# 0                 Date       YEAR  Day of the Year    Weekno.    T2M_MAX
# 1  2013-01-01 00:00:00       2013                1          1      19.93
# 2  2013-02-01 00:00:00       2013                2          1      19.87
# 3  2013-03-01 00:00:00       2013                3          1       19.6
# 4  2013-04-01 00:00:00       2013                4          1      20.38
#
#   District 1.1 District 1.2 District 2 District 2.1 District 2.2  ...  \
# 0      T2M_MIN     Rainfall    T2M_MAX      T2M_MIN     Rainfall  ...
# 1         3.15            0       16.9         5.26            0  ...
# 2          3.3            0       17.3         4.28            0  ...
# 3         3.45            0      17.51         4.23            0  ...
# 4         3.72            0      17.93         6.14            0  ...
#
#   District 29.2 District 30 District 30.1 District 30.2 District 31  \
# ...

# %%
new_header = df.iloc[0]

# %%
df = df[1:]

# %%
df.head()
# Out:
#             Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 District 1  \
# 1  2013-01-01 00:00:00       2013          1          1      19.93
# 2  2013-02-01 00:00:00       2013          2          1      19.87
# 3  2013-03-01 00:00:00       2013          3          1       19.6
# 4  2013-04-01 00:00:00       2013          4          1      20.38
# 5  2013-05-01 00:00:00       2013          5          1      18.98
#
#   District 1.1 District 1.2 District 2 District 2.1 District 2.2  ...  \
# 1         3.15            0       16.9         5.26            0  ...
# 2          3.3            0       17.3         4.28            0  ...
# 3         3.45            0      17.51         4.23            0  ...
# 4         3.72            0      17.93         6.14            0  ...
# 5         2.93            0      16.81         3.19            0  ...
#
#   District 29.2 District 30 District 30.1 District 30.2 District 31  \
# 1             0       27.02          9.94             0       25.55
# ...

# %%
df.columns = new_header

# %%
df.head()
# Out:
# 0                 Date  YEAR Day of the Year Weekno. T2M_MAX T2M_MIN Rainfall  \
# 1  2013-01-01 00:00:00  2013               1       1   19.93    3.15        0
# 2  2013-02-01 00:00:00  2013               2       1   19.87     3.3        0
# 3  2013-03-01 00:00:00  2013               3       1    19.6    3.45        0
# 4  2013-04-01 00:00:00  2013               4       1   20.38    3.72        0
# 5  2013-05-01 00:00:00  2013               5       1   18.98    2.93        0
#
# 0 T2M_MAX T2M_MIN Rainfall  ... Rainfall T2M_MAX T2M_MIN Rainfall T2M_MAX  \
# 1    16.9    5.26        0  ...        0   27.02    9.94        0   25.55
# 2    17.3    4.28        0  ...        0    23.6    8.71        0   22.35
# 3   17.51    4.23        0  ...        0   23.41    4.31        0   22.57
# 4   17.93    6.14        0  ...        0   24.73    4.75        0    23.7
# 5   16.81    3.19        0  ...        0   24.04    5.03        0   22.12
#
# 0 T2M_MIN Rainfall T2M_MAX T2M_MIN Rainfall
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4014 entries, 1 to 4014
# Data columns (total 100 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             4014 non-null   object
#  1   YEAR             4014 non-null   object
#  2   Day of the Year  4014 non-null   object
#  3   Weekno.          4014 non-null   object
#  4   T2M_MAX          4014 non-null   object
#  5   T2M_MIN          4014 non-null   object
#  6   Rainfall         4014 non-null   object
#  7   T2M_MAX          4014 non-null   object
#  8   T2M_MIN          4014 non-null   object
#  9   Rainfall         4014 non-null   object
#  10  T2M_MAX          4014 non-null   object
#  11  T2M_MIN          4014 non-null   object
#  12  Rainfall         4014 non-null   object
#  13  T2M_MAX          4014 non-null   object
#  14  T2M_MIN          4014 non-null   object
#  15  Rainfall         4014 non-null   object
# ...

# %%
df.iloc[:, 0] = pd.to_datetime(df.iloc[:, 0])

# %%
df.iloc[:, 1:] = df.iloc[:, 1:].astype(float)

# %%
df.dtypes
# Out:
# 0
# Date               object
# YEAR               object
# Day of the Year    object
# Weekno.            object
# T2M_MAX            object
#                     ...
# T2M_MIN            object
# Rainfall           object
# T2M_MAX            object
# T2M_MIN            object
# Rainfall           object
# Length: 100, dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['YEAR'] = pd.to_datetime(df['YEAR'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4014 entries, 1 to 4014
# Data columns (total 100 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             4014 non-null   datetime64[ns]
#  1   YEAR             4014 non-null   datetime64[ns]
#  2   Day of the Year  4014 non-null   object
#  3   Weekno.          4014 non-null   object
#  4   T2M_MAX          4014 non-null   object
#  5   T2M_MIN          4014 non-null   object
#  6   Rainfall         4014 non-null   object
#  7   T2M_MAX          4014 non-null   object
#  8   T2M_MIN          4014 non-null   object
#  9   Rainfall         4014 non-null   object
#  10  T2M_MAX          4014 non-null   object
#  11  T2M_MIN          4014 non-null   object
#  12  Rainfall         4014 non-null   object
#  13  T2M_MAX          4014 non-null   object
#  14  T2M_MIN          4014 non-null   object
#  15  Rainfall         4014 non-null   object
# ...

# %%
df.head()
# Out:
# 0       Date                          YEAR Day of the Year Weekno. T2M_MAX  \
# 1 2013-01-01 1970-01-01 00:00:00.000002013             1.0     1.0   19.93
# 2 2013-02-01 1970-01-01 00:00:00.000002013             2.0     1.0   19.87
# 3 2013-03-01 1970-01-01 00:00:00.000002013             3.0     1.0    19.6
# 4 2013-04-01 1970-01-01 00:00:00.000002013             4.0     1.0   20.38
# 5 2013-05-01 1970-01-01 00:00:00.000002013             5.0     1.0   18.98
#
# 0 T2M_MIN Rainfall T2M_MAX T2M_MIN Rainfall  ... Rainfall T2M_MAX T2M_MIN  \
# 1    3.15      0.0    16.9    5.26      0.0  ...      0.0   27.02    9.94
# 2     3.3      0.0    17.3    4.28      0.0  ...      0.0    23.6    8.71
# 3    3.45      0.0   17.51    4.23      0.0  ...      0.0   23.41    4.31
# 4    3.72      0.0   17.93    6.14      0.0  ...      0.0   24.73    4.75
# 5    2.93      0.0   16.81    3.19      0.0  ...      0.0   24.04    5.03
#
# 0 Rainfall T2M_MAX T2M_MIN Rainfall T2M_MAX T2M_MIN Rainfall
# ...

# %%
df['YEAR']=df['Date'].dt.year

# %%
df[['Date', 'YEAR']]
# Out:
# 0          Date  YEAR
# 1    2013-01-01  2013
# 2    2013-02-01  2013
# 3    2013-03-01  2013
# 4    2013-04-01  2013
# 5    2013-05-01  2013
# ...         ...   ...
# 4010 2023-12-24  2023
# 4011 2023-12-25  2023
# 4012 2023-12-26  2023
# 4013 2023-12-27  2023
# 4014 2023-12-28  2023
#
# [4014 rows x 2 columns]

# %%
d1 = df[['Date', 'YEAR']]

# %%
df.iloc[:,2:] = df.iloc[:,2:].astype(float)

# %%
df.iloc[]

# %%
d2 = df.iloc[:,2:].astype(float)

# %%
dd.dtypes
# Out:
# 0
# Day of the Year    float64
# Weekno.            float64
# T2M_MAX            float64
# T2M_MIN            float64
# Rainfall           float64
#                     ...
# T2M_MIN            float64
# Rainfall           float64
# T2M_MAX            float64
# T2M_MIN            float64
# Rainfall           float64
# Length: 98, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4014 entries, 1 to 4014
# Data columns (total 100 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             4014 non-null   datetime64[ns]
#  1   YEAR             4014 non-null   datetime64[ns]
#  2   Day of the Year  4014 non-null   object
#  3   Weekno.          4014 non-null   object
#  4   T2M_MAX          4014 non-null   object
#  5   T2M_MIN          4014 non-null   object
#  6   Rainfall         4014 non-null   object
#  7   T2M_MAX          4014 non-null   object
#  8   T2M_MIN          4014 non-null   object
#  9   Rainfall         4014 non-null   object
#  10  T2M_MAX          4014 non-null   object
#  11  T2M_MIN          4014 non-null   object
#  12  Rainfall         4014 non-null   object
#  13  T2M_MAX          4014 non-null   object
#  14  T2M_MIN          4014 non-null   object
#  15  Rainfall         4014 non-null   object
# ...

# %%
df = pd.concat([d1,d2], axis=1)

# %%
df.dtypes
# Out:
# 0
# Date               datetime64[ns]
# YEAR                        int32
# Day of the Year           float64
# Weekno.                   float64
# T2M_MAX                   float64
#                         ...
# T2M_MIN                   float64
# Rainfall                  float64
# T2M_MAX                   float64
# T2M_MIN                   float64
# Rainfall                  float64
# Length: 100, dtype: object

# %%
df.describe()
# Out:
# 0                     Date         YEAR  Day of the Year      Weekno.  \
# count                 4014  4014.000000      4014.000000  4014.000000
# mean   2018-06-30 12:00:00  2017.996263       182.955904    26.968112
# min    2013-01-01 00:00:00  2013.000000         1.000000     1.000000
# 25%    2015-10-01 06:00:00  2015.000000        92.000000    14.000000
# 50%    2018-06-30 12:00:00  2018.000000       183.000000    27.000000
# 75%    2021-03-29 18:00:00  2021.000000       274.000000    40.000000
# max    2023-12-28 00:00:00  2023.000000       366.000000    53.000000
# std                    NaN     3.160423       105.355255    15.056666
#
# 0          T2M_MAX      T2M_MIN     Rainfall      T2M_MAX      T2M_MIN  \
# count  4014.000000  4014.000000  4014.000000  4014.000000  4014.000000
# mean     33.489696    19.681114     1.256846    32.981682    20.073767
# min      15.110000     1.190000     0.000000    14.450000     1.160000
# ...

# %%
for i in df.count():
    if i < 4014:
        
        print(i)

# %%
for i in df.isnull().sum():
    if i > 0:
        
        print(i)

# %%
df.head()
# Out:
# 0       Date  YEAR  Day of the Year  Weekno.  T2M_MAX  T2M_MIN  Rainfall  \
# 1 2013-01-01  2013              1.0      1.0    19.93     3.15       0.0
# 2 2013-02-01  2013              2.0      1.0    19.87     3.30       0.0
# 3 2013-03-01  2013              3.0      1.0    19.60     3.45       0.0
# 4 2013-04-01  2013              4.0      1.0    20.38     3.72       0.0
# 5 2013-05-01  2013              5.0      1.0    18.98     2.93       0.0
#
# 0  T2M_MAX  T2M_MIN  Rainfall  ...  Rainfall  T2M_MAX  T2M_MIN  Rainfall  \
# 1    16.90     5.26       0.0  ...       0.0    27.02     9.94       0.0
# 2    17.30     4.28       0.0  ...       0.0    23.60     8.71       0.0
# 3    17.51     4.23       0.0  ...       0.0    23.41     4.31       0.0
# 4    17.93     6.14       0.0  ...       0.0    24.73     4.75       0.0
# 5    16.81     3.19       0.0  ...       0.0    24.04     5.03       0.0
#
# 0  T2M_MAX  T2M_MIN  Rainfall  T2M_MAX  T2M_MIN  Rainfall
# ...

# %%
df_monthly = df.groupby(pd.Grouper(key='Date', freq='M')).sum()

# %%
df_monthly
# Out:
# 0            YEAR  Day of the Year  Weekno.  T2M_MAX  T2M_MIN  Rainfall  \
# Date
# 2013-01-31  62403           2428.0    370.0   814.87   368.36     27.05
# 2013-02-28  56364           2846.0    426.0   813.85   398.32     16.58
# 2013-03-31  62403           3573.0    533.0  1018.93   564.08     11.00
# 2013-04-30  60390           4053.0    601.0  1084.39   647.53      5.58
# 2013-05-31  62403           4756.0    701.0  1208.52   748.42     13.29
# ...           ...              ...      ...      ...      ...       ...
# 2023-08-31  62713           6540.0    948.0  1090.83   760.66     32.19
# 2023-09-30  60690           6867.0    993.0  1044.10   746.70     59.51
# 2023-10-31  62713           7723.0   1117.0  1034.87   700.99     36.60
# 2023-11-30  60690           7989.0   1154.0   893.39   556.91      7.70
# 2023-12-31  56644           7814.0   1129.0   819.71   474.80      2.94
#
# 0           T2M_MAX  T2M_MIN  Rainfall  T2M_MAX  ...  Rainfall  T2M_MAX  \
# ...

# %%
for i in df_monthly.columns:
    if i == ''

# %%
df_monthly['Monthly_Rainfall'] = df_monthly.loc[:, df_monthly.columns.str.startswith('Rainfall')].sum(axis=1)

# %%
df_monthly.head()
# Out:
# 0            YEAR  Day of the Year  Weekno.  T2M_MAX  T2M_MIN  Rainfall  \
# Date
# 2013-01-31  62403           2428.0    370.0   814.87   368.36     27.05
# 2013-02-28  56364           2846.0    426.0   813.85   398.32     16.58
# 2013-03-31  62403           3573.0    533.0  1018.93   564.08     11.00
# 2013-04-30  60390           4053.0    601.0  1084.39   647.53      5.58
# 2013-05-31  62403           4756.0    701.0  1208.52   748.42     13.29
#
# 0           T2M_MAX  T2M_MIN  Rainfall  T2M_MAX  ...  T2M_MAX  T2M_MIN  \
# Date                                             ...
# 2013-01-31   794.96   361.39     36.91   834.25  ...   890.04   389.79
# 2013-02-28   780.67   409.35     20.28   837.80  ...   841.80   416.71
# 2013-03-31   995.30   557.16     24.25  1037.67  ...  1049.46   564.52
# 2013-04-30  1068.35   648.32     12.93  1098.82  ...  1098.84   649.15
# 2013-05-31  1215.23   761.22     29.82  1213.83  ...  1220.77   766.14
#
# ...

# %%
Monthly_Rainfall_MM = df_monthly.iloc[:,-1]

# %%
all_data = pd.DataFrame(Monthly_Rainfall_MM )

# %%
all_data.head()
# Out:
#             Monthly_Rainfall
# Date
# 2013-01-31            860.53
# 2013-02-28            878.11
# 2013-03-31            923.53
# 2013-04-30            647.59
# 2013-05-31            994.04

# %%
df.head()
# Out:
# 0       Date  YEAR  Day of the Year  Weekno.  T2M_MAX  T2M_MIN  Rainfall  \
# 1 2013-01-01  2013              1.0      1.0    19.93     3.15       0.0
# 2 2013-02-01  2013              2.0      1.0    19.87     3.30       0.0
# 3 2013-03-01  2013              3.0      1.0    19.60     3.45       0.0
# 4 2013-04-01  2013              4.0      1.0    20.38     3.72       0.0
# 5 2013-05-01  2013              5.0      1.0    18.98     2.93       0.0
#
# 0  T2M_MAX  T2M_MIN  Rainfall  ...  Rainfall  T2M_MAX  T2M_MIN  Rainfall  \
# 1    16.90     5.26       0.0  ...       0.0    27.02     9.94       0.0
# 2    17.30     4.28       0.0  ...       0.0    23.60     8.71       0.0
# 3    17.51     4.23       0.0  ...       0.0    23.41     4.31       0.0
# 4    17.93     6.14       0.0  ...       0.0    24.73     4.75       0.0
# 5    16.81     3.19       0.0  ...       0.0    24.04     5.03       0.0
#
# 0  T2M_MAX  T2M_MIN  Rainfall  T2M_MAX  T2M_MIN  Rainfall
# ...

# %%
df_monthly_max = df.groupby(pd.Grouper(key='Date', freq='M'))['T2M_MAX'].max().reset_index()

# %%
df_monthly_max
# Out:
# 0         Date  T2M_MAX  T2M_MAX  T2M_MAX  T2M_MAX  T2M_MAX  T2M_MAX  T2M_MAX  \
# 0   2013-01-31    43.67    43.06    44.15    44.17    43.50    44.54    43.41
# 1   2013-02-28    43.08    42.57    43.76    44.07    44.08    43.79    42.76
# 2   2013-03-31    44.10    43.73    44.40    44.44    44.44    44.66    43.82
# 3   2013-04-30    44.71    44.77    44.96    44.83    44.54    45.15    43.99
# 4   2013-05-31    44.94    45.31    44.97    45.61    46.20    45.17    44.22
# ..         ...      ...      ...      ...      ...      ...      ...      ...
# 127 2023-08-31    43.00    42.00    41.00    49.00    41.90    41.00    40.00
# 128 2023-09-30    42.00    41.00    42.00    48.00    42.70    42.00    40.00
# 129 2023-10-31    43.00    42.00    43.00    47.00    43.00    43.00    41.00
# 130 2023-11-30    42.00    40.00    44.00    46.00    44.00    44.00    42.00
# 131 2023-12-31    44.00    44.00    45.00    47.00    45.00    45.00    44.00
#
# ...

# %%
dum = df_monthly_max.iloc[:,1:]

# %%
dum
# Out:
# 0    T2M_MAX  T2M_MAX  T2M_MAX  T2M_MAX  T2M_MAX  T2M_MAX  T2M_MAX  T2M_MAX  \
# 0      43.67    43.06    44.15    44.17    43.50    44.54    43.41    43.08
# 1      43.08    42.57    43.76    44.07    44.08    43.79    42.76    42.15
# 2      44.10    43.73    44.40    44.44    44.44    44.66    43.82    43.98
# 3      44.71    44.77    44.96    44.83    44.54    45.15    43.99    44.37
# 4      44.94    45.31    44.97    45.61    46.20    45.17    44.22    45.72
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 127    43.00    42.00    41.00    49.00    41.90    41.00    40.00    42.00
# 128    42.00    41.00    42.00    48.00    42.70    42.00    40.00    42.00
# 129    43.00    42.00    43.00    47.00    43.00    43.00    41.00    42.00
# 130    42.00    40.00    44.00    46.00    44.00    44.00    42.00    43.00
# 131    44.00    44.00    45.00    47.00    45.00    45.00    44.00    44.00
#
# ...

# %%
dum['Max_Number'] = dum.max(axis=1)

# %%
dum.head()
# Out:
# 0  T2M_MAX  T2M_MAX  T2M_MAX  T2M_MAX  T2M_MAX  T2M_MAX  T2M_MAX  T2M_MAX  \
# 0    43.67    43.06    44.15    44.17    43.50    44.54    43.41    43.08
# 1    43.08    42.57    43.76    44.07    44.08    43.79    42.76    42.15
# 2    44.10    43.73    44.40    44.44    44.44    44.66    43.82    43.98
# 3    44.71    44.77    44.96    44.83    44.54    45.15    43.99    44.37
# 4    44.94    45.31    44.97    45.61    46.20    45.17    44.22    45.72
#
# 0  T2M_MAX  T2M_MAX  ...  T2M_MAX  T2M_MAX  T2M_MAX  T2M_MAX  T2M_MAX  \
# 0    42.22    43.98  ...    42.84    43.69    41.15    41.89    42.37
# 1    41.58    44.16  ...    42.33    42.76    40.73    41.26    41.23
# 2    43.30    44.93  ...    42.01    41.69    40.90    43.13    41.42
# 3    42.88    45.55  ...    42.46    43.12    40.73    43.29    40.96
# 4    44.50    47.12  ...    45.02    45.68    43.48    45.22    43.69
#
# 0  T2M_MAX  T2M_MAX  T2M_MAX  T2M_MAX  Max_Number
# ...

# %%
Maximum_Temperature = dum['Max_Number']

# %%
Maximum_Temperature = pd.DataFrame(Maximum_Temperature)

# %%
Maximum_Temperature
# Out:
#      Max_Number
# 0         44.83
# 1         45.16
# 2         45.60
# 3         45.74
# 4         48.05
# ..          ...
# 127       49.00
# 128       48.00
# 129       47.00
# 130       46.00
# 131       47.00
#
# [132 rows x 1 columns]

# %%
all_data['Maximum_Temperature'] = Maximum_Temperature

# %%
all_data
# Out:
#             Monthly_Rainfall  Maximum_Temperature
# Date
# 2013-01-31            860.53                  NaN
# 2013-02-28            878.11                  NaN
# 2013-03-31            923.53                  NaN
# 2013-04-30            647.59                  NaN
# 2013-05-31            994.04                  NaN
# ...                      ...                  ...
# 2023-08-31           1842.90                  NaN
# 2023-09-30           3575.49                  NaN
# 2023-10-31           1010.25                  NaN
# 2023-11-30            913.46                  NaN
# 2023-12-31            152.46                  NaN
#
# [132 rows x 2 columns]

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 132 entries, 2013-01-31 to 2023-12-31
# Freq: M
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Monthly_Rainfall     132 non-null    float64
#  1   Maximum_Temperature  0 non-null      float64
# dtypes: float64(2)
# memory usage: 7.2 KB
