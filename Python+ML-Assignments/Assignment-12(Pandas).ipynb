# %% [markdown]
# # 1.
# Write
# a
# Pandas
# program
# to
# replace
# all
# the
# NaN
# values
# with
# mean
# in
# a
# column
# of
# a
# DataFrame

# %% [markdown]
# # 2.
# Write
# a
# Pandas
# program
# to
# create
# and
# display
# a
# DataFrame
# from
# a
# specified
# dictionary data which has the index labels

# %% [markdown]
# # 3.
# Write a Pandas program to get the first 3 rows of a given DataFrame.

# %% [markdown]
# # 4.
# Write
# a
# Pandas
# program
# to
# select
# the
# first
# 2
# rows,
# 2
# columns,
# and
# specific
# two
# columns

# %% [markdown]
# # 5.
# Write
# a
# Pandas
# program
# to
# select
# the
# specified
# columns
# and
# rows
# from
# a
# given
# DataFrame

# %% [markdown]
# # 6.
# Write
# a
# Pandas
# program
# to
# detect
# missing
# values
# of
# a
# given
# DataFrame.
# Display
# True or False

# %% [markdown]
# # 7.
# Write
# a
# Pandas
# program
# to
# count
# the
# number
# of
# missing
# values
# in
# each
# column
# of
# a
# given DataFrame

# %% [markdown]
# # 8.
# Write
# a
# Pandas
# program
# to
# find
# and
# replace
# the
# missing
# values
# in
# a
# given
# DataFrame
# which do not have any valuable information.
# ○
# Example:
# ○
# Missing values: ?, --
# ○
# Replace those values with NaN

# %% [markdown]
# # 9.
# Write
# a
# Pandas
# program
# to
# drop
# the
# rows
# where
# at
# least
# one
# element
# is
# missing
# in
# a
# given DataFrame

# %% [markdown]
# # 10.
# Write
# a
# Pandas
# program
# to
# drop
# the
# rows
# where
# all
# elements
# are
# missing
# in
# a
# given
# DataFrame

# %% [markdown]
# # 11.
# Write
# a
# Pandas
# program
# to
# keep
# the
# rows
# with
# at
# least
# 2
# NaN
# values
# in
# a
# given
# DataFrame

# %% [markdown]
# # 12.
# Write a Pandas program to keep the valid entries of a given DataFrame.

# %% [markdown]
# # 13.
# Write
# a
# Pandas
# program
# to
# calculate
# the
# total
# number
# of
# missing
# values
# in
# a
# DataFrame

# %% [markdown]
# # 14.
# Write
# a
# Pandas
# program
# to
# replace
# NaNs
# with
# a
# single
# constant
# value
# in
# specified
# columns in a DataFrame

# %% [markdown]
# # 15.
# Write
# a
# Pandas
# program
# to
# replace
# NaNs
# with
# the
# median
# or
# mean
# of
# the
# specified
# columns in a given DataFrame

# %% [markdown]
# # 16.
# Write a Pandas program to find the Indexes of missing values in a given DataFrameVelocity Corporate Training Center, Pune
# Topic: Pandas

# %% [markdown]
# # 17.
# Write
# a
# Pandas
# program
# to
# select
# rows
# from
# a
# given
# DataFrame
# based
# on
# values
# in
# some columns

# %% [markdown]
# # 18.
# Write a Pandas program to change the order of a DataFrame columns

# %% [markdown]
# # 19.
# Write a Pandas program to add one row in an existing DataFrame

# %% [markdown]
# # 20.
# Write a Pandas program to delete DataFrame row(s) based on a given column value

# %% [markdown]
# # 21.
# Write a Pandas program to select a row of series/DataFrame by given integer index

# %% [markdown]
# # 22.
# Write
# a
# Pandas
# program
# to
# get
# the
# length
# of
# the
# string
# present
# in
# a
# given
# column
# in
# a
# DataFrame

# %% [markdown]
# # 23.
# Write
# a
# Pandas
# program
# to
# swap
# the
# cases
# of
# a
# specified
# character
# column
# in
# a
# given
# DataFrame

# %% [markdown]
# # 24.
# Write
# a
# Pandas
# program
# to
# convert
# a
# specified
# character
# column
# in
# upper/lower
# cases in a given DataFrame.

# %% [markdown]
# # 25.
# Write
# a
# Pandas
# program
# to
# remove
# whitespaces,
# left-sided
# whitespaces,
# and
# right-sided whitespaces of the string values of a given pandas series

# %% [markdown]
# # 26.
# Write
# a
# Pandas
# program
# to
# extract
# years
# between
# 1800
# to
# 2200
# from
# the
# specified
# column of a given DataFrame.
# df = pd.DataFrame({
# 'company_code': ['c0001','c0002','c0003', 'c0003', 'c0004'],
# 'year': ['year 1800','year 1700','year 2300', 'year 1900', 'year 2200']
# })

# %% [markdown]
# # 27.
# Write a Pandas program to join the two given dataframes along rows

# %% [markdown]
# # 28.
# Write a Pandas program to join the two given dataframes along with columns

# %% [markdown]
# # 29.
# Write
# a
# Pandas
# program
# to
# join
# the
# two
# given
# dataframes
# along
# rows
# and
# merge
# with
# another dataframe along with the common column id.

# %% [markdown]
# # 30.
# Write
# a
# Pandas
# program
# to
# join
# the
# two
# dataframes
# using
# the
# common
# column
# of
# both dataframes

# %% [markdown]
# # 31.
# Write
# a
# Pandas
# program
# to
# join
# (left
# join)
# the
# two
# dataframes
# using
# keys
# from
# the
# left
# dataframe only

# %% [markdown]
# # 32.
# Write
# a
# Pandas
# program
# to
# join
# two
# dataframes
# using
# keys
# from
# the
# right
# dataframe
# only.

# %% [markdown]
# # 33.
# Write a Pandas program to merge two given datasets using multiple join keys

# %% [markdown]
# # 34.
# Write a Pandas program to merge two given dataframes with different columnsVelocity Corporate Training Center, Pune
# Topic: Pandas

# %% [markdown]
# # 35.
# Write
# a
# Pandas
# program
# to
# sort
# movies
# on
# runtime
# in
# descending
# order(Use
# movies
# dataset)

# %% [markdown]
# # 36.
# Write a Pandas program to get the longest runtime and shortest runtime

# %% [markdown]
# # 37.
# Write a Pandas program to get Action and crime movies

# %% [markdown]
# # 38.
# Write
# a
# Pandas
# program
# to
# count
# the
# city-wise
# number
# of
# people
# from
# a
# given
# data
# set (city, name of the person)
# Sample data:
# City                 Number of people
# 0 California       4
# 1 Georgia         2
# 2 Los Angeles  4

# %% [markdown]
# # 39.
# Write
# a
# Pandas
# program
# to
# replace
# all
# the
# NaN
# values
# with
# Zero's
# in
# a
# column
# of
# a
# DataFrame

# %% [markdown]
# # 40.
# Write a Pandas program to drop a list of rows from a specified DataFrame
# Sample data:
# Original DataFrame
# col1 col2 col3
# 0 1 4 7
# 1 4 5 8
# 2 3 6 9
# 3 4 7 0
# 4 5 8 1
