# %% [markdown]
# # 1.
# Explain the Decision Tree algorithm in detail.

# %% [markdown]
# # 2.
# What are the Steps for Making a decision tree?

# %% [markdown]
# # 3.
# What are the Algorithms used in the Decision Tree?

# %% [markdown]
# # 4.
# What are Parametric and Nonparametric Machine Learning Algorithms

# %% [markdown]
# # 5.
# Explain Decision tree Key terms: Root Node, Decision Node/Branch Node, Leaf or
# Terminal Node.

# %% [markdown]
# # 6.
# What are Assumptions while creating a Decision Tree?

# %% [markdown]
# # 7.
# What is entropy?

# %% [markdown]
# # 8.
# What is Information Gain?

# %% [markdown]
# # 9.
# What is Gini Index?

# %% [markdown]
# # 10.
# What is a Puresubset?

# %% [markdown]
# # 11.
# What is the difference between Entropy and Gini Impurity(Gini Index)

# %% [markdown]
# # 12.
# How do you calculate the entropy of children nodes after the split based on a
# feature?

# %% [markdown]
# # 13.
# Does Decision Tree require feature scaling?

# %% [markdown]
# # 14.
# Explain feature selection using the information gain/entropy technique?

# %% [markdown]
# # 15.
# What are Techniques to avoid Overfitting in Decision Tree?

# %% [markdown]
# # 16.
# How to tune hyperparameters in decision trees Classifier?

# %% [markdown]
# # 17.
# What is pruning in the Decision Tree?

# %% [markdown]
# # 18.
# How is a splitting point chosen for continuous variables in decision trees?

# %% [markdown]
# # 19.
# What are the advantages and disadvantages of the Decision Tree?

# %% [markdown]
# # 20.
# What is Decision Tree Regressor?

# %% [markdown]
# # 21.
# How is Splitting Decided for Decision Trees Regressor?

# %% [markdown]
# # 22.
# Explain Linear regression vs decision trees regression

# %% [markdown]
# # 23.
# How to tune hyperparameters in decision trees regression?

# %% [markdown]
# # 24.
# What is max_depth in the Decision Tree?

# %% [markdown]
# # 25.
# What are the min_samples_split and min_samples_leaf hyperparameters?

# %% [markdown]
# # 26.
# What are the Applications of Decision Trees?
