# %% [markdown]
# # 1.
# Write a python program to check that a string contains only a certain set of
# characters (in this case a-z,  A-Z, and 0-9).

# %% [markdown]
# # 2.
# Create a program to split a string by only the first occurrence of any substring.

# %% [markdown]
# # 3.
# Code that would match a string that has an a followed by zero or more b's.

# %% [markdown]
# # 4.
# Wap to find Three-digit numbers followed by space followed by two-digit
# numbers in a string.

# %% [markdown]
# # 5.
# Write a Python program that matches a string that has an a followed by one
# or more b's.

# %% [markdown]
# # 6.
# Write a program to search inform in a string both in uppercase & in lowercase.
# (INFORM or  inform)

# %% [markdown]
# # 7.
# WAP that matches a string that has an a followed by zero or one 'b'. .

# %% [markdown]
# # 8.
# WAP that matches a string that has an a followed by three 'b'. .

# %% [markdown]
# # 9.
# Write a Python program that matches a string that has an a followed by two to
# three 'b'.

# %% [markdown]
# # 10.
# Find all the words starting in range of k-n using a for loop & re.

# %% [markdown]
# # 11.
# Write a Python program to find sequences of lowercase letters joined with an
# underscore.

# %% [markdown]
# # 12.
# Write a program to find the sequences of one upper case letter followed by
# lower case letters.

# %% [markdown]
# # 13.
# Write a program that matches a string that has an 'a' followed by anything,
# ending in 'b'.

# %% [markdown]
# # 14.
# WAP that matches a word at the beginning of a string.

# %% [markdown]
# # 15.
# Write a program that matches a word at the end of a string, with optional
# punctuation.

# %% [markdown]
# # 16.
# Write a Python program that matches a word containing 'z'.

# %% [markdown]
# # 17.
# Write a program that matches a word containing 'z', not at the start or end of
# the word.

# %% [markdown]
# # 18.
# Write a program to match a string that contains only upper and lowercase
# letters, numbers, and underscores.

# %% [markdown]
# # 19.
# WAP where a string will start with a specific number.

# %% [markdown]
# # 20.
# Write a Python program to remove leading zeros from an IP address.Velocity Corporate Training Center, Pune
# Regular Expression

# %% [markdown]
# # 21.
# Write a program to check for a number at the end of a string. .

# %% [markdown]
# # 22.
# Code a program to search the numbers (0-9) of length between 1 to 3 in a
# given string. . "Exercises number 1, 12, 13, and 345 are important"

# %% [markdown]
# # 23.
# Write a program to search some literals strings in a string. .
# Sample text : 'The quick brown fox jumps over the lazy dog.'
# Searched words : 'fox', 'dog', 'horse'

# %% [markdown]
# # 24.
# Write a Python program to search a literals string in a string and also find the
# location within the  original string where the pattern occurs. .
# Sample text : 'The quick brown fox jumps over the lazy dog.'
# Searched words : 'fox'

# %% [markdown]
# # 25.
# Write a code to find a common substrings within a string.
# Sample text : 'Python exercises, PHP exercises, C# exercises'
# Pattern : 'exercises'
# Note: There are two instances of exercises in the input string.

# %% [markdown]
# # 26.
# Write a program to find the occurrence and position of the substrings within a
# string. .

# %% [markdown]
# # 27.
# Write a code to replace whitespaces with an underscore and vice versa. .

# %% [markdown]
# # 28.
# How would you remove all whitespaces from a string?

# %% [markdown]
# # 29.
# Write a Python program to match if two words from a list of words starting with
# the letter 'P'

# %% [markdown]
# # 30.
# Write a code to find all words starting with 'a' or 'e' in a given string. .

# %% [markdown]
# # 31.
# Write a Python program to separate and print the numbers and their position
# of a given string.

# %% [markdown]
# # 32.
# Write a Python program to replace all occurrences of space, comma, or dot
# with a colon.

# %% [markdown]
# # 33.
# Write a program to replace maximum 2 occurrences of space, comma, or dot
# with a colon.

# %% [markdown]
# # 34.
# Write a Python program to find all three, four, five characters long words in a
# string.

# %% [markdown]
# # 35.
# Write a program to extract values between quotation marks of a string.

# %% [markdown]
# # 36.
# How would you remove multiple spaces in a string?
