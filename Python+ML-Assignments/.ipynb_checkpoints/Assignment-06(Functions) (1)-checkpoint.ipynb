# %% [markdown]
# # 1.
# What
# is
# a
# lambda
# function
# in
# Python,
# and
# what
# is
# its
# purpose?

# %% [markdown]
# # 2.
# Explain
# the
# syntax
# of
# a
# lambda
# function.

# %% [markdown]
# # 3.
# Can
# you
# define
# a
# lambda
# function
# with
# multiple
# arguments?
# If
# so,
# how?

# %% [markdown]
# # 4.
# What
# is
# the
# difference
# between
# a
# lambda
# function
# and
# a
# regular
# function
# in
# Python?

# %% [markdown]
# # 5.
# Explain
# the
# term
# "anonymous
# function"
# in
# the
# context
# of
# lambda
# functions

# %% [markdown]
# # 6.
# Write
# a
# Python
# program
# to
# sort
# a
# list
# of
# tuples
# using
# Lambda.

# %% [markdown]
# # 7.
# How
# do
# you
# sort
# a
# list
# of
# dictionaries
# based
# on
# a
# specific
# key
# using
# a
# lambda
# function?

# %% [markdown]
# # 8.
# Write
# a
# Python
# program
# to
# find
# square
# and
# cube
# every
# number
# in
# a
# given
# list
# of
# integers
# using
# Lambda

# %% [markdown]
# # 9.
# Write
# a
# Python
# program
# to
# find
# if
# a
# given
# string
# starts
# with
# a
# given
# character
# using
# Lambda

# %% [markdown]
# # 10.
# Write
# a
# Python
# program
# to
# check
# whether
# a
# given
# string
# is
# a
# number
# or
# not
# using
# Lambda

# %% [markdown]
# # 11.
# Write
# a
# Python
# program
# to
# create
# a
# Fibonacci
# series
# using
# Lambda
# Functions

# %% [markdown]
# # 12.
# Write
# a
# Python
# program
# to
# find
# the
# intersection
# of
# two
# given
# arrays(Lists)
# using
# Lambda

# %% [markdown]
# # 13.
# Write
# a
# Python
# program
# to
# rearrange
# positive
# and
# negative
# numbers
# in
# a
# given
# array
# using
# Lambda

# %% [markdown]
# # 14.
# Write
# a
# Python
# program
# to
# count
# the
# even,
# and
# odd
# numbers
# in
# a
# given
# array
# of
# integers
# using
# Lambda

# %% [markdown]
# # 15.
# Write
# a
# Python
# program
# to
# add
# two
# given
# lists
# using
# map
# and
# lambda

# %% [markdown]
# # 16.
# Write
# a
# Python
# program
# to
# find
# numbers
# divisible
# by
# nineteen
# or
# thirteen
# from
# a
# list
# of
# numbers
# using
# Lambda

# %% [markdown]
# # 17.
# Write
# a
# Python
# program
# to
# find
# palindromes
# in
# a
# given
# list
# of
# strings
# using
# Lambda

# %% [markdown]
# # 18.
# Write
# a
# Python
# program
# to
# find
# all
# anagrams
# of
# a
# string
# in
# a
# given
# list
# of
# strings
# using
# lambda

# %% [markdown]
# # 19.
# Write
# a
# Python
# program
# that
# multiplies
# each
# number
# of
# a
# given
# list
# with
# a
# given
# number
# using
# the
# lambda
# function.
# Print
# the
# result

# %% [markdown]
# # 20.
# Write
# a
# Python
# program
# to
# calculate
# the
# sum
# of
# the
# positive
# and
# negative
# numbers
# of
# a
# given
# list
# of
# numbers
# using
# the
# lambda
# function

# %% [markdown]
# # 21.
# Write
# a
# Python
# program
# to
# find
# the
# list
# with
# maximum
# and
# minimum
# length
# using
# lambda

# %% [markdown]
# # 22.
# Write
# a
# Python
# program
# to
# check
# whether
# a
# specified
# list
# is
# sorted
# or
# not
# using
# lambda

# %% [markdown]
# # 23.
# Write
# a
# Python
# program
# to
# remove
# all
# elements
# from
# a
# given
# list
# present
# in
# another
# list
# using
# lambda.

# %% [markdown]
# # 24.
# Write
# a
# Python
# program
# to
# convert
# a
# string
# element
# to
# an
# integer
# inside
# a
# given
# tuple
# using
# lambda

# %% [markdown]
# # 25.
# Write
# a
# Python
# program
# to
# count
# the
# occurrences
# of
# the
# items
# in
# a
# given
# list
# using
# lambda

# %% [markdown]
# # 26.
# Write
# a
# Python
# program
# to
# add
# three
# given
# lists
# using
# Python
# map
# and
# lambda

# %% [markdown]
# # 27.
# Write
# a
# Python
# program
# to
# listify
# the
# list
# of
# given
# strings
# individually
# using
# a
# Python
# map
# function.

# %% [markdown]
# # 28.
# Write
# a
# Python
# program
# to
# square
# the
# elements
# of
# a
# list
# using
# map()
# function.

# %% [markdown]
# # 29.
# Write
# a
# Python
# program
# to
# add
# two
# given
# lists
# and
# find
# the
# difference
# between
# lists.
# Use
# map()
# function

# %% [markdown]
# # 30.
# Write
# a
# Python
# program
# to
# convert
# a
# given
# list
# of
# integers
# and
# a
# tuple
# of
# integers
# in
# a
# list
# of
# strings

# %% [markdown]
# # 31.
# Write
# a
# Python
# program
# to
# compute
# the
# sum
# of
# elements
# of
# a
# given
# array
# of
# integers,
# using
# the
# map()
# function

# %% [markdown]
# # 32.
# Write
# a
# Python
# program
# to
# count
# the
# same
# pair
# in
# two
# given
# lists.
# use
# map()
# function

# %% [markdown]
# # 33.
# Write
# a
# Python
# program
# to
# convert
# a
# given
# list
# of
# strings
# into
# a
# list
# of
# lists
# using
# map
# function

# %% [markdown]
# # 34.
# Write
# a
# Python
# program
# to
# convert
# a
# given
# list
# of
# tuples
# to
# a
# list
# of
# strings
# using
# map
# function

# %% [markdown]
# # 35.
# Python
# program
# to
# find
# the
# diff.
# between
# two
# lists
# using
# filter()
# function.

# %% [markdown]
# # 36.
# Python
# program
# to
# remove
# stop
# words
# from
# string
# using
# filter()
# function.

# %% [markdown]
# # 37.
# Python
# program
# to
# find
# common
# items
# in
# two
# arrays
# using
# lambda
# and
# filter()
# function.

# %% [markdown]
# # 38.
# Python
# program
# to
# filter
# odd
# numbers
# from
# the
# list
# using
# filter()
# function

# %% [markdown]
# # 39.
# Python
# program
# to
# filter
# even
# numbers
# from
# the
# list
# using
# filter()
# function

# %% [markdown]
# # 40.
# Python
# program
# that
# filters
# non-vowels
# from
# the
# list
# using
# filter()
# function
