# %% [markdown]
# # 1.
# Write a Python program to sort a list of tuples using
# Lambda.

# %% [markdown]
# # 2.
# Write a Python program to sort a list of dictionaries
# using Lambda

# %% [markdown]
# # 3.
# Write
# a
# Python
# program
# to
# find
# square
# and
# cube
# every
# number
# in
# a
# given
# list
# of
# integers using Lambda

# %% [markdown]
# # 4.
# Write
# a
# Python
# program
# to
# find
# if
# a
# given
# string
# starts
# with
# a
# given
# character
# using
# Lambda

# %% [markdown]
# # 5.
# Write
# a
# Python
# program
# to
# check
# whether
# a
# given
# string
# is
# number
# or
# not
# using
# Lambda

# %% [markdown]
# # 6.
# Write a Python program to create Fibonacci series
# using Lambda

# %% [markdown]
# # 7.
# Write a Python program to find the intersection of
# two given arrays using Lambda

# %% [markdown]
# # 8.
# Write
# a
# Python
# program
# to
# rearrange
# positive
# and
# negative
# numbers
# in
# a
# given
# array
# using Lambda

# %% [markdown]
# # 9.
# Write
# a
# Python
# program
# to
# count
# the
# even,
# odd
# numbers
# in
# a
# given
# array
# of
# integers
# using Lambda

# %% [markdown]
# # 10.
# Write a Python program to add two given lists using
# map and lambda

# %% [markdown]
# # 11.
# Write
# a
# Python
# program
# to
# find
# numbers
# divisible
# by
# nineteen
# or
# thirteen
# from
# a
# list
# of
# numbers using Lambda

# %% [markdown]
# # 12.
# Write a Python program to find palindromes in a given
# list of strings using Lambda

# %% [markdown]
# # 13.
# Write
# a
# Python
# program
# to
# find
# all
# anagrams
# of
# a
# string
# in
# a
# given
# list
# of
# strings
# using
# lambda

# %% [markdown]
# # 14.
# Write
# a
# Python
# program
# that
# multiplies
# each
# number
# of
# a
# given
# list
# with
# a
# given
# number using lambda function. Print the result

# %% [markdown]
# # 15.
# Write
# a
# Python
# program
# to
# calculate
# the
# sum
# of
# the
# positive
# and
# negative
# numbers
# of
# a given list of numbers using lambda function

# %% [markdown]
# # 16.
# Write
# a
# Python
# program
# to
# find
# the
# list
# with
# maximum
# and
# minimum
# length
# using
# lambda

# %% [markdown]
# # 17.
# Write
# a
# Python
# program
# to
# check
# whether
# a
# specified
# list
# is
# sorted
# or
# not
# using
# lambda

# %% [markdown]
# # 18.
# Write
# a
# Python
# program
# to
# remove
# all
# elements
# from
# a
# given
# list
# present
# in
# another
# list using lambda.

# %% [markdown]
# # 19.
# Write a Python program to convert string element to
# integer inside a given tuple using

# %% [markdown]
# # 20.
# Write
# a
# Python
# program
# to
# count
# the
# occurrences
# of
# the
# items
# in
# a
# given
# list
# using
# lambda

# %% [markdown]
# # 21.
# Write a Python program to add three given lists using
# Python map and lambda

# %% [markdown]
# # 22.
# Write a Python program to listify the list of given strings individually using Python map

# %% [markdown]
# # 23.
# Write a Python program to square the elements of a
# list using map() function

# %% [markdown]
# # 24.
# Write
# a
# Python
# program
# to
# add
# two
# given
# lists
# and
# find
# the
# difference
# between
# lists.
# Use map() function

# %% [markdown]
# # 25.
# Write
# a
# Python
# program
# to
# convert
# a
# given
# list
# of
# integers
# and
# a
# tuple
# of
# integers
# in
# a
# list of strings

# %% [markdown]
# # 26.
# Write
# a
# Python
# program
# to
# compute
# the
# sum
# of
# elements
# of
# an
# given
# array
# of
# integers, use map() function

# %% [markdown]
# # 27.
# Write a Python program to count the same pair in two
# given lists. use map() function

# %% [markdown]
# # 28.
# Write
# a
# Python
# program
# to
# convert
# a
# given
# list
# of
# strings
# into
# list
# of
# lists
# using
# map
# function

# %% [markdown]
# # 29.
# Write
# a
# Python
# program
# to
# convert
# a
# given
# list
# of
# tuples
# to
# a
# list
# of
# strings
# using
# map
# function

# %% [markdown]
# # 30.
# Python program to find the diff. between two lists
# using filter() function

# %% [markdown]
# # 31.
# Python program to remove stop words from string using
# filter() function

# %% [markdown]
# # 32.
# Python program to find common items in two arrays
# using lambda and filter() function

# %% [markdown]
# # 33.
# Python program to filter odd numbers from the list
# using filter() function

# %% [markdown]
# # 34.
# Python program to filter even numbers from the list
# using filter() function

# %% [markdown]
# # 35.
# Python program that filters non-vowels from the list
# using filter() function
