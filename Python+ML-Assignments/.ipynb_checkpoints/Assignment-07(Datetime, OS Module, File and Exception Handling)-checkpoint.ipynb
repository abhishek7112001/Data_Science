# %% [markdown]
# # 1.
# Write a Python program to read an entire text file

# %% [markdown]
# # 2.
# Write a Python program to read the first n lines of
# a file

# %% [markdown]
# # 3.
# Write a Python program to append text to a file and
# display the text

# %% [markdown]
# # 4.
# Write a Python program to read the last n lines of
# a file

# %% [markdown]
# # 5.
# Write a Python program to read a file line by line
# and store it into a list

# %% [markdown]
# # 6.
# Write a Python program to count the number of lines
# in a text file

# %% [markdown]
# # 7.
# Write a Python program to count the frequency of words
# in a file

# %% [markdown]
# # 8.
# Write a Python program to copy the contents of a file
# to another file

# %% [markdown]
# # 9.
# Write a Python script to display the various Date
# Time formats - Go to the editor
# a) Current date and time
# b) Current year
# c) Month of year
# d) Week number of the year
# e) Weekday of the week
# f) Day of year
# g) Day of the month
# h) Day of week

# %% [markdown]
# # 10.
# Write a Python program to determine whether a given
# year is a leap year

# %% [markdown]
# # 11.
# Write a Python program to convert a string to datetime.
# Go to the editor
# ○
# Sample String : Jan 1 2014 2:43PM
# ○
# Expected Output : 2014-07-01 14:43:00

# %% [markdown]
# # 12.
# Write a Python program to subtract five days from
# current date

# %% [markdown]
# # 13.
# Write a Python program to print yesterday, today,
# tomorrow

# %% [markdown]
# # 14.
# Write a Python program to print next 5 days starting
# from today

# %% [markdown]
# # 15.
# Write a Python program to drop microseconds from DateTime

# %% [markdown]
# # 16.
# Write a Python program to find the date of the first
# Monday of a given week

# %% [markdown]
# # 17.
# Write a Python program to select all the Sundays of
# a specified year

# %% [markdown]
# # 18.
# Write a Python program to create a file and write
# some text and rename the file name

# %% [markdown]
# # 19.
# What are different methods available in the OS module
# for creating a directory?

# %% [markdown]
# # 20.
# Explain os.listdir() method.

# %% [markdown]
# # 21.
# What are different methods for removing directories
# and files in Python?

# %% [markdown]
# # 22.
# What are exceptions in Python?

# %% [markdown]
# # 23.
# What are Built-in exceptions?

# %% [markdown]
# # 24.
# What are User-defined Exceptions?

# %% [markdown]
# # 25.
# When would you not use try-except?

# %% [markdown]
# # 26.
# Can try-except catch the error if a file can’t be
# opened?
