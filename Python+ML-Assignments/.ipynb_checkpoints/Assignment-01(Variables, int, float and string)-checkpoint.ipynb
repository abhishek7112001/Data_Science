# %% [markdown]
# # 1.
# What
# are
# the
# key
# features
# of
# Python?

# %% [markdown]
# # 2.
# What
# are
# the
# Data
# T ypes
# in
# Python?

# %% [markdown]
# # 3.
# What
# are
# local
# variables
# and
# global
# variables
# in
# Python?

# %% [markdown]
# # 4.
# How
# do
# you
# write
# comments
# in
# Python?
# And
# Why
# Comments
# are
# important?

# %% [markdown]
# # 5.
# How
# to
# comment
# on
# multiple
# lines
# in
# Python?

# %% [markdown]
# # 6.
# What
# do
# you
# mean
# by
# Python
# literals?

# %% [markdown]
# # 7.
# What
# are
# the
# dif ferent
# ways
# to
# assign
# value
# to
# variables?

# %% [markdown]
# # 8.
# What
# are
# the
# Escape
# Characters
# in
# Python?

# %% [markdown]
# # 9.
# What
# are
# the
# dif ferent
# ways
# to
# perform
# string
# formatting?
# Explain
# with
# an
# example.

# %% [markdown]
# # 10.
# W rite
# a
# program
# to
# print
# every
# character
# of
# a
# string
# entered
# by
# the
# user
# in
# a
# new
# line
# using
# a
# loop
# 1

# %% [markdown]
# # 1.
# W rite
# a
# program
# to
# find
# the
# length
# of
# the
# string
# "machine
# learning"
# with
# and
# without
# using
# the
# len
# function.

# %% [markdown]
# # 12.
# W rite
# a
# program
# to
# check
# if
# the
# word
# 'orange'
# is
# present
# in
# the
# "This
# is
# orange
# juice".

# %% [markdown]
# # 13.
# W rite
# a
# Python
# program
# to
# count
# the
# number
# of
# vowels,
# consonants,
# digits
# and
# special
# characters
# in
# a
# string

# %% [markdown]
# # 14.
# W rite
# a
# Python
# program
# to
# count
# Uppercase,
# Lowercase,
# special
# characters,
# and
# numeric
# values
# in
# a
# given
# string.

# %% [markdown]
# # 15.
# W rite
# a
# program
# to
# make
# a
# new
# string
# with
# all
# the
# consonants
# deleted
# from
# the
# string
# "Hello,
# have
# a
# good
# day".

# %% [markdown]
# # 16.
# W rite
# a
# Python
# program
# to
# remove
# the
# nth
# index
# character
# from
# a
# non-empty
# string.

# %% [markdown]
# # 17.
# W rite
# a
# Python
# program
# to
# change
# a
# given
# string
# to
# a
# new
# string
# where
# the
# first
# and
# last
# characters
# have
# been
# exchanged.

# %% [markdown]
# # 18.
# W rite
# a
# Python
# program
# to
# count
# the
# occurrences
# of
# each
# word
# in
# a
# given
# sentence.

# %% [markdown]
# # 19.
# How
# do
# you
# count
# the
# occurrence
# of
# a
# given
# character
# in
# a
# string?

# %% [markdown]
# # 20.
# W rite
# a
# program
# to
# find
# the
# last
# 10
# characters
# of
# a
# string.

# %% [markdown]
# # 21.
# W AP
# to
# convert
# a
# given
# string
# to
# all
# uppercase
# if
# it
# contains
# at
# least
# 2
# uppercase
# characters
# in
# the
# first
# 4
# characters.

# %% [markdown]
# # 22.
# W rite
# a
# Python
# program
# to
# remove
# a
# new
# line
# from
# a
# string.

# %% [markdown]
# # 23.
# W rite
# a
# Python
# program
# to
# swap
# commas
# and
# dots
# in
# a
# string
# ○
# Sample
# string:
# "

# %% [markdown]
# # 24.
# W rite
# a
# Python
# program
# to
# find
# the
# first
# repeated
# character
# in
# a
# given
# string

# %% [markdown]
# # 25.
# W rite
# a
# Python
# program
# to
# find
# the
# second
# most
# repeated
# word
# in
# a
# given
# string

# %% [markdown]
# # 26.
# Python
# program
# to
# Count
# Even
# and
# Odd
# numbers
# in
# a
# string.

# %% [markdown]
# # 27.
# How
# do
# you
# check
# if
# a
# string
# contains
# only
# digits?

# %% [markdown]
# # 28.
# How
# do
# you
# remove
# a
# given
# character/word
# from
# String?

# %% [markdown]
# # 29.
# W rite
# a
# Python
# program
# to
# remove
# the
# characters
# which
# have
# odd
# index
# values
# of
# a
# given
# string

# %% [markdown]
# # 30.
# W rite
# a
# Python
# function
# to
# reverse
# a
# string
# if
# its
# length
# is
# a
# multiple
# of
# 5

# %% [markdown]
# # 31.
# W rite
# a
# Python
# program
# to
# format
# a
# number
# with
# a
# percentage(

# %% [markdown]
# # 32.
# W rite
# a
# Python
# program
# to
# reverse
# words
# in
# a
# string

# %% [markdown]
# # 33.
# W rite
# a
# Python
# program
# to
# swap
# cases
# of
# a
# given
# string

# %% [markdown]
# # 34.
# W rite
# a
# Python
# program
# to
# remove
# spaces
# from
# a
# given
# string

# %% [markdown]
# # 35.
# W rite
# a
# Python
# program
# to
# remove
# duplicate
# characters
# of
# a
# given
# string

# %% [markdown]
# # 36.
# W rite
# a
# Python
# Program
# to
# find
# the
# area
# of
# a
# circle

# %% [markdown]
# # 37.
# W rite
# a
# Python
# Program
# to
# find
# the
# Sum
# of
# squares
# of
# first
# n
# natural
# numbers

# %% [markdown]
# # 38.
# W rite
# a
# Python
# Program
# to
# find
# the
# Sum
# of
# cubes
# of
# first
# n
# natural
# numbers

# %% [markdown]
# # 39.
# W rite
# a
# Python
# Program
# to
# find
# simple
# interest
# and
# compound
# interest

# %% [markdown]
# # 40.
# W rite
# a
# Python
# program
# to
# check
# whether
# a
# number
# is
# Prime
# or
# not
