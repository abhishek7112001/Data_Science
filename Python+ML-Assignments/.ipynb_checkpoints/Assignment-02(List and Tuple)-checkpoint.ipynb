# %% [markdown]
# # 1.
# What
# is
# a
# list
# in
# Python?

# %% [markdown]
# # 2.
# How
# do
# you
# create
# an
# empty
# list?

# %% [markdown]
# # 3.
# Explain
# the
# difference
# between
# append()
# and
# extend()
# methods
# for
# lists.

# %% [markdown]
# # 4.
# Write
# a
# Python
# program
# to
# append
# a
# list
# to
# the
# second
# list

# %% [markdown]
# # 5.
# What
# is
# list
# comprehension?

# %% [markdown]
# # 6.
# What
# are
# the
# different
# ways
# to
# remove
# an
# element
# from
# a
# list?

# %% [markdown]
# # 7.
# What
# is
# the
# difference
# between
# indexing
# and
# Slicing?

# %% [markdown]
# # 8.
# Python
# program
# to
# find
# the
# smallest
# and
# largest
# number
# in
# a
# list
# (with
# and
# without
# using
# min-max
# function)

# %% [markdown]
# # 9.
# Python
# program
# to
# interchange
# first
# and
# last
# elements
# in
# a
# list.

# %% [markdown]
# # 10.
# Python
# program
# to
# swap
# two
# elements
# in
# a
# list

# %% [markdown]
# # 11.
# Python
# program
# to
# Reverse
# a
# List
# with
# and
# without
# reverse/reversed
# functions

# %% [markdown]
# # 12.
# What
# are
# the
# different
# ways
# to
# find
# the
# length
# of
# a
# list

# %% [markdown]
# # 13.
# Python
# program
# to
# find
# the
# sum
# of
# elements
# in
# a
# list

# %% [markdown]
# # 14.
# Python
# program
# to
# Multiply
# all
# numbers
# in
# the
# list

# %% [markdown]
# # 15.
# Write
# a
# Python
# program
# to
# find
# the
# third-largest
# number
# in
# a
# list

# %% [markdown]
# # 16.
# How
# do
# you
# iterate
# over
# elements
# in
# a
# list?

# %% [markdown]
# # 17.
# Python
# program
# to
# Count
# Even
# and
# Odd
# numbers
# in
# a
# List

# %% [markdown]
# # 18.
# WAP
# to
# make
# new
# lists,
# containing
# only
# numbers
# which
# are
# divisible
# by
# 4,
# 6,
# 8,
# 10,
# 3,
# 5,
# 7,
# and
# 9
# in
# separate
# lists
# for
# range(0,151)

# %% [markdown]
# # 19.
# From
# a
# list
# containing
# ints,
# strings,
# and
# floats,
# make
# three
# lists
# to
# store
# them
# separately .

# %% [markdown]
# # 20.
# Write
# a
# Python
# program
# to
# check
# whether
# a
# list
# contains
# a
# sublist

# %% [markdown]
# # 21.
# Write
# a
# Python
# program
# to
# generate
# all
# sublists
# of
# a
# list

# %% [markdown]
# # 22.
# Write
# a
# Python
# program
# to
# find
# common
# elements
# between
# the
# two
# list

# %% [markdown]
# # 23.
# WAP
# to
# remove
# duplicates
# from
# a
# list
# while
# preserving
# the
# original
# order

# %% [markdown]
# # 24.
# How
# to
# flatten
# a
# list
# in
# Python?

# %% [markdown]
# # 25.
# How
# to
# sort
# a
# list
# in
# ascending
# and
# descending
# order
# without
# using
# the
# sort
# function?

# %% [markdown]
# # 26.
# Difference
# between
# sort
# and
# sorted?

# %% [markdown]
# # 27.
# Difference
# between
# reverse
# and
# reversed?

# %% [markdown]
# # 28.
# Difference
# between
# copy
# and
# deep
# copy?

# %% [markdown]
# # 29.
# How
# to
# check
# whether
# the
# list
# is
# empty
# or
# not?

# %% [markdown]
# # 30.
# How
# to
# concatenate
# two
# lists?

# %% [markdown]
# # 31.
# Write
# a
# Python
# program
# to
# convert
# a
# list
# of
# multiple
# integers
# into
# a
# single
# integer
# ○
# [11,
# 33,
# 50]
# >>>
# 113350

# %% [markdown]
# # 32.
# You
# are
# given
# a
# list
# of
# integer
# elements.
# Make
# a
# new
# list
# that
# will
# store
# a
# square
# of
# elements
# of
# the
# previous
# list.
# (With
# and
# without
# list
# comprehension)
# ○
# i.
# Input_list
# =
# [2,5,6,12]
# ○
# ii.
# Output_list
# =
# [4,25,36,144]

# %% [markdown]
# # 33.
# WAP
# to
# create
# two
# lists,
# one
# containing
# all
# even
# numbers
# and
# the
# other
# containing
# all
# odd
# numbers
# between
# 0
# to
# 151

# %% [markdown]
# # 34.
# You
# have
# two
# lists.
# Combine
# them
# into
# a
# single
# list,
# alternating
# elements
# from
# each

# %% [markdown]
# # 35.
# Write
# a
# function
# to
# determine
# if
# a
# given
# list
# is
# a
# palindrome

# %% [markdown]
# # 36.
# Use
# list
# comprehension
# to
# create
# a
# list
# of
# squares
# for
# even
# numbers
# and
# cubes
# for
# odd
# numbers
# from
# 1
# to
# 10

# %% [markdown]
# # 37.
# Generate
# a
# list
# of
# prime
# numbers
# between
# 1
# to

# %% [markdown]
# # 100.

# %% [markdown]
# # 38.
# Create
# a
# list
# of
# words
# from
# a
# sentence
# that
# have
# a
# length
# greater
# than

# %% [markdown]
# # 5.

# %% [markdown]
# # 39.
# Given
# two
# lists
# of
# numbers,
# create
# a
# list
# of
# products
# of
# corresponding
# elements,
# but
# only
# include
# positive
# products.

# %% [markdown]
# # 40.
# What
# is
# a
# Tuple
# in
# Python?

# %% [markdown]
# # 41.
# How
# do
# you
# create
# an
# empty
# tuple?

# %% [markdown]
# # 42.
# How
# do
# you
# concatenate
# two
# tuples?

# %% [markdown]
# # 43.
# What
# is
# the
# purpose
# of
# the
# count()
# and
# index()
# methods
# for
# tuples?

# %% [markdown]
# # 44.
# What
# is
# the
# difference
# between
# a
# List
# and
# a
# Tuple?

# %% [markdown]
# # 45.
# How
# to
# sort
# a
# tuple?

# %% [markdown]
# # 46.
# Given
# a
# tuple
# representing
# a
# date
# (year,
# month,
# day),
# write
# a
# function
# to
# unpack
# the
# tuple
# and
# print
# the
# date
# in
# the
# format
# "YYYY-MM-DD."

# %% [markdown]
# # 47.
# Create
# a
# function
# to
# sort
# a
# list
# of
# tuples
# based
# on
# the
# second
# element
# of
# each
# tuple

# %% [markdown]
# # 48.
# Explain
# a
# scenario
# where
# using
# a
# tuple
# would
# be
# more
# suitable
# than
# using
# a
# list

# %% [markdown]
# # 49.
# Write
# a
# function
# to
# convert
# a
# tuple
# to
# a
# list
# and
# vice
# versa.

# %% [markdown]
# # 50.
# Write
# a
# program
# that
# performs
# element-wise
# addition
# on
# two
# tuples.
