# %% [markdown]
# # 1.
# Simple Linear Regression:
# If
# a
# single
# independent
# variable
# is
# used
# to
# predict
# the
# value
# of
# a
# numerical
# dependent
# variable,
# then
# such
# a
# Linear
# Regression
# algorithm
# is
# called
# Simple
# Linear Regression.
# y = mx + c

# %% [markdown]
# # 2.
# Multiple Linear regression:
# If
# more
# than
# one
# independent
# variable
# is
# used
# to
# predict
# the
# value
# of
# a
# numerical
# dependent
# variable,
# then
# such
# a
# Linear
# Regression
# algorithm
# is
# called
# Multiple Linear Regression.
# y = m1x1 + m2x2 + ... + mNxN + c
# y = Dependent V ariable (T arget V ariable)
# x = Independent V ariable (predictor V ariable)
# c = intercept of the line (Gives an additional degree of freedom)
# m = Linear regression coef ficient (scale factor to each input value).
# ❖
# Loss Function(Cost Function)
# :
# ●
# The
# loss
# is
# the
# error
# in
# our
# predicted
# value
# of
# m
# and
# c.
# Our
# goal
# is
# to
# minimize
# this error to obtain the most accurate value of m and c.
# ●
# We will use the Mean Squared Error function to calculate the loss
# ❖
# Gradient Descent Algorithm
# ●
# Gradient
# descent
# is
# an
# iterative
# optimization
# algorithm
# to
# find
# the
# minimize
# the
# Loss Function.
# ●
# Gradient
# descent
# is
# a
# method
# of
# updating
# m
# and
# c
# values
# to
# minimize
# the
# cost
# function (MSE) and to get the best fit line(regression line)
# ●
# Best
# Fit
# Line
# :
# When
# working
# with
# linear
# regression,
# our
# main
# goal
# is
# to
# find
# the
# best
# fit
# line
# which
# means
# the
# error
# between
# predicted
# values
# and
# actual
# values
# should
# be
# minimized.
# The
# best
# fit
# line
# will
# always
# have
# the
# least
# Mean
# squares
# error.
# ●
# A
# regression
# model
# uses
# gradient
# descent
# to
# update
# the
# coefficients
# of
# the
# line
# (
# m
# and
# c
# )
# by
# reducing
# the
# cost
# function
# by
# a
# random
# selection
# of
# coefficient
# values
# and
# then
# iteratively
# updating
# the
# values
# to
# reach
# the
# minimum
# cost
# function.
# ●
# To
# update
# m
# and
# c,
# we
# take
# gradients
# from
# the
# cost
# function.
# To
# find
# these
# gradients, we take partial derivatives for m and c.
# ●
# Calculate
# the
# partial
# derivative
# of
# the
# loss
# function
# with
# respect
# to
# m,
# and
# plug
# in
# the current values of x, y , m, and c in it to obtain the derivative value D.
# ○
# ○
# ●
# Global minima:
# It is a point that obtains the absolute
# lowest value of our function
# ●
# Learning
# Rate
# :
# It
# determines
# the
# size
# of
# the
# steps
# that
# are
# taken
# by
# the
# gradient
# descent algorithm
# ●
# If
# α (
# Learning Rate) is very small, it would take a long time to converge and
# become computationally expensive.
# ●
# If
# α
# is large, it may fail to converge and overshoot the minimum.
# ●
# The most commonly used rates are :

# %% [markdown]
# # 3.
# ●
# Gradient Descent variants
# :
# There
# are
# three
# types
# of
# gradient
# descent
# methods
# based
# on
# the
# amount
# of
# data
# used to calculate the gradient:

# %% [markdown]
# # 1.
# Batch gradient descent

# %% [markdown]
# # 2.
# Stochastic gradient descent

# %% [markdown]
# # 3.
# Mini-batch gradient descent
# ❖
# Assumptions of Linear Regression:

# %% [markdown]
# # 1.
# Linearity
# :
# Relationship
# between
# the
# independent
# and
# dependent
# variables
# to
# be
# linear .

# %% [markdown]
# # 2.
# No
# Multicollinearity
# (
# Independence
# ):
# Observations
# are
# independent
# of
# each
# other .

# %% [markdown]
# # 3.
# Normality of Residual

# %% [markdown]
# # 4.
# Homoscedasticity
# : The variance of residual is the
# same for any value of X.

# %% [markdown]
# # 1.
# Linearity
# :
# Relationship between the independent and dependent
# variables to be linear

# %% [markdown]
# # 1.
# Coef ficient of correlation

# %% [markdown]
# # 2.
# Scatter Plot

# %% [markdown]
# # 3.
# Correlation matrix

# %% [markdown]
# # 1.
# Log transformation

# %% [markdown]
# # 2.
# Square root transformation

# %% [markdown]
# # 3.
# Reciprocal transformation

# %% [markdown]
# # 2. No Multicollinearity:
# ●
# Multicollinearity
# (or
# collinearity)
# occurs
# when
# one
# independent
# variable
# in
# a
# regression model is linearly correlated with another independent variable.
# ●
# This
# means
# that
# an
# independent
# variable
# can
# be
# predicted
# from
# another
# independent variable in a regression model
# ●
# Multicollinearity
# can
# be
# a
# problem
# in
# a
# regression
# model
# because
# we
# would
# not
# be
# able
# to
# distinguish
# between
# the
# individual
# effects
# of
# the
# independent
# variables
# on the dependent
# ●
# Y = M1X1 + M2X2 + C
# ●
# Coef ficient
# M1
# is
# the
# increase
# in
# Y
# for
# a
# unit
# increase
# in
# X1
# while
# keeping
# X2
# constant.
# But
# since
# X1
# and
# X2
# are
# highly
# correlated,
# changes
# in
# X1
# would
# also
# cause changes in X2 and we would not be able to see their individual ef fect on Y.
# ●
# Multicollinearity
# may
# not
# affect
# the
# accuracy
# of
# the
# model
# as
# much.
# But
# we
# might
# lose
# reliability
# in
# determining
# the
# effects
# of
# individual
# features
# in
# your
# model
# –
# and
# that can be a problem when it comes to interpretability .

# %% [markdown]
# # 1.
# VIF (V ariable Inflation Factors):
# The
# VIF
# score
# of
# an
# independent
# variable
# represents
# how
# well
# the
# variable
# is
# explained by other independent variables.
# VIF = 1 → No correlation
# VIF = 1 to 5 → Moderate correlation
# VIF >10 → High correlation

# %% [markdown]
# # 2.
# Correlation matrix / Correlation plot

# %% [markdown]
# # 3.
# Scatter plots

# %% [markdown]
# # 1.
# Dropping variables

# %% [markdown]
# # 2.
# Combining variables

# %% [markdown]
# # 3. Normality of the residuals
# Residuals: The dif ference between the actual y value and the estimated y value
# Residuals
# = (Ya-Yp)
# A normal distribution has some important properties:

# %% [markdown]
# # 1.
# The mean, median, and mode all represent the center of the distribution.

# %% [markdown]
# # 2.
# the distribution is a bell shape

# %% [markdown]
# # 3.
# ≈68%
# of
# the
# data
# falls
# within
# 1
# standard
# deviation
# of
# the
# mean,
# ≈95%
# of
# the
# data
# falls
# within
# 2
# STD
# of
# the
# mean
# and
# ≈

# %% [markdown]
# # 1. Graphs for Normality test:

# %% [markdown]
# # 1. Distribution curve, Histogram (sns. distplot,
# sns.kdeplot)

# %% [markdown]
# # 2. Q-Q or Quantile-Quantile Plot

# %% [markdown]
# # 2. Statistical Tests for Normality(Hypothesis Testing):

# %% [markdown]
# # 1. Shapiro-Wilk test

# %% [markdown]
# # 2. Kolmogorov-Smirnov test

# %% [markdown]
# # 3. D'Agostino's K-squared test

# %% [markdown]
# # 1.
# Check and remove outliers

# %% [markdown]
# # 2.
# Apply a nonlinear transformation to the independent and/or dependent variable
# a.
# Log transformation
# b.
# Square root transformation
# c.
# Reciprocal transformation

# %% [markdown]
# # 4. Homoscedasticity:
# ●
# Residuals
# have
# constant
# variance
# at
# every
# level
# of
# x.
# This
# is
# known
# as
# homoscedasticity
# .
# When
# this
# is
# not
# the
# case,
# the
# residuals
# are
# said
# to
# suffer
# from
# heteroscedasticity
# .
# ●
# When
# heteroscedasticity
# is
# present
# in
# a
# regression
# analysis,
# the
# results
# of
# the
# analysis become hard to trust

# %% [markdown]
# # 1.
# Scatter plot between fitted value and residual plot.

# %% [markdown]
# # 1.
# Transform
# the
# dependent
# variable(Y)
# :
# log
# transformation
# of
# the
# dependent
# variable

# %% [markdown]
# # 2.
# Redefine the dependent variable

# %% [markdown]
# # 3.
# Use
# weighted
# regression:
# This
# type
# of
# regression
# assigns
# a
# weight
# to
# each
# data point based on the variance of its fitted value.❖
# Advantages:

# %% [markdown]
# # 1.
# Simple to implement and easier to interpret the output coef ficients.

# %% [markdown]
# # 2.
# When
# you
# know
# the
# dependent
# and
# independent
# variables
# have
# a
# linear
# relationship,
# this
# algorithm
# is
# the
# best
# to
# use
# because
# it’s
# less
# complex
# as
# compared to other algorithms.

# %% [markdown]
# # 3.
# Linear
# Regression
# is
# prone
# to
# over-fitting
# but
# it
# can
# be
# avoided
# using
# some
# dimensionality
# reduction
# techniques,
# regularization
# (L1
# and
# L2)
# techniques,
# and
# cross-validation.
# ❖
# Disadvantages:

# %% [markdown]
# # 1.
# If the independent features are correlated it may af fect performance.

# %% [markdown]
# # 2.
# it is only ef ficient for linear data(High Corr between x and Y)

# %% [markdown]
# # 3.
# Sometimes a lot of feature engineering is required.

# %% [markdown]
# # 4.
# Scaling is Required: predictors have a mean of

# %% [markdown]
# # 0.

# %% [markdown]
# # 5.
# It is often quite prone to noise and overfitting.

# %% [markdown]
# # 6.
# It is sensitive to missing values.

# %% [markdown]
# # 7.
# It is sensitive to Outliers
# ❖
# Applications:

# %% [markdown]
# # 1.
# Forecasting the data

# %% [markdown]
# # 2.
# Analyzing the time series

# %% [markdown]
# # 3.
# Price Prediction

# %% [markdown]
# # 4.
# Salary Prediction❖
# Evaluation Metrics for Linear Regression:

# %% [markdown]
# # 1.
# Mean Absolute Error(MAE): It is most Robust to outliers.

# %% [markdown]
# # 2.
# Mean Squared Error(MSE)

# %% [markdown]
# # 3.
# Root Mean Squared Error(RMSE)

# %% [markdown]
# # 4.
# R-squared or Coef ficient of Determination:
# a.
# SSE(Sum of Squared Error
# b.
# SSR(Sum of Squares due to Regression)
# c.
# SST(Sum of Squares Total or Total Error)

# %% [markdown]
# # 5.
# Adjusted R Squared
