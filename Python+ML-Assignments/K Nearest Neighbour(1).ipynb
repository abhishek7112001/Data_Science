# %% [markdown]
# # 1.
# Load the data

# %% [markdown]
# # 2.
# Select the number K of the neighbors

# %% [markdown]
# # 3.
# Calculate the distance with all points

# %% [markdown]
# # 4.
# Sort the distances in ascending order

# %% [markdown]
# # 5.
# Pick the first K entries from the sorted collection

# %% [markdown]
# # 6.
# Classification
# :
# A
# class
# label
# assigned
# to
# the
# majority
# of
# K
# Nearest
# Neighbors
# from the training dataset is considered as a predicted class for the new data point

# %% [markdown]
# # 7.
# Regression
# : return the mean of the K label
# ❖
# Overview of KNN in 4 steps:
# Using K-Nearest Neighbour , we predict the category of the test point from the
# available class labels by finding the distance between the test point and trained k
# nearest feature values
# ❖
# How to Choose the right value of K?:
# ●
# K is a crucial parameter in the KNN algorithm.
# ●
# In
# the
# below
# image,
# if
# we
# proceed
# with
# K=3,
# then
# we
# predict
# that
# test
# input
# belongs
# to
# class
# B,
# and
# if
# we
# continue
# with
# K=7,
# then
# we
# predict
# that
# test
# input
# belongs to class A.
# ●
# That’ s
# why
# the
# K
# value
# has
# a
# powerful
# effect
# on
# KNN
# performance.
# But
# there
# are
# no pre-defined statistical methods to find the most favorable value of K.

# %% [markdown]
# # 1.
# Using error curves
# :
# ●
# At
# low
# K
# values,
# there
# is
# overfitting
# of
# data/high
# variance.
# Therefore
# test
# error is high and train error is low(
# overfitting
# )
# ●
# K=1
# in
# train
# data,
# the
# error
# is
# always
# zero,
# because
# the
# nearest
# neighbor
# to that point is that point itself.
# ●
# As we increase the value for K, the test error is reduced.

# %% [markdown]
# # 2.
# K-value:
# K value should be odd while considering binary(two-class)
# classification
# ❖
# Minkowski Distance:
# It
# is
# a
# metric
# intended
# for
# real-valued
# vector
# spaces.
# We
# can
# calculate
# Minkowski
# distance
# only
# in
# a
# normed
# vector
# space,
# which
# means
# in
# a
# space
# where
# distances
# can
# be represented as a vector that has a length and the lengths cannot be negative.
# The distance can be calculated using the below formula -
# Minkowski distance is the generalized distance metric. Here generalized means that we
# can manipulate the above formula to calculate the distance between two data points in
# different ways.
# p = 1 >>  Manhattan Distance and p = 2 >> Euclidean Distance

# %% [markdown]
# # 1.
# Manhattan Distance(p = 1 ):
# We use Manhattan Distance if we need to calculate
# the distance between two
# data points in a grid-like path.

# %% [markdown]
# # 2.
# Euclidean Distance(p = 2)
# : It is one of the most used
# distance metrics
# ❖
# Advantages:

# %% [markdown]
# # 1.
# The algorithm is simple and easy to implement.

# %% [markdown]
# # 2.
# There’ s
# no
# need
# to
# build
# a
# model,
# tune
# several
# parameters,
# or
# make
# additional
# assumptions.

# %% [markdown]
# # 3.
# The
# algorithm
# is
# versatile.
# It
# can
# be
# used
# for
# classification,
# regression,
# and
# search (as we will see in the next section).

# %% [markdown]
# # 4.
# Work with any number of classes, not just binary classifiers.

# %% [markdown]
# # 5.
# Efficient method for small datasets
# ❖
# Disadvantages:

# %% [markdown]
# # 1.
# The
# computation
# cost
# is
# high
# because
# of
# calculating
# the
# distance
# between
# the
# data points for all the training samples.

# %% [markdown]
# # 2.
# Data Scaling(Feature scaling) is required(
# normalization
# or standardization)

# %% [markdown]
# # 3.
# Always needs to determine the value of K which may be complex sometime

# %% [markdown]
# # 4.
# Doesn’t
# work
# as
# expected
# when
# working
# with
# a
# big
# number
# of
# features/
# parameters(Large datasets take longer to process):
# a.
# Select best features using:
# i.
# Feature selection
# ii.
# Feature Extraction: Principal component analysis

# %% [markdown]
# # 5.
# Noisy data can result in over-fitting or under-fitting of data

# %% [markdown]
# # 6.
# Sensitive to Outliers
# ❖
# Applications:

# %% [markdown]
# # 1.
# Text mining

# %% [markdown]
# # 2.
# Agriculture

# %% [markdown]
# # 3.
# Finance

# %% [markdown]
# # 4.
# Medical

# %% [markdown]
# # 5.
# Facial recognition

# %% [markdown]
# # 6.
# Recommendation systems (Amazon, Hulu, Netflix, etc)
# ❖
# Hyperparameters:
# ●
# n_neighbors
# :
# To
# define
# the
# required
# neighbors
# of
# the
# algorithm.
# Usually ,
# it
# takes

# %% [markdown]
# # 5.
# ●
# p=2:
# ○
# p = 1 >>  Manhattan Distance
# ○
# p = 2 >> Euclidean Distance❖
# Evaluation Metrics for KNN:

# %% [markdown]
# # 1.
# Classification
# a.
# Confusion Matrix
# b.
# MultiLabel Confusion Matrix
# c.
# Accuracy Score
# d.
# Classification Report

# %% [markdown]
# # 2.
# Regression
# :
# a.
# Mean Squared Error
# b.
# Root Mean Squared Error
# c.
# Mean Absolute Error
# d.
# R-Squared value❖
# Feature Scaling:
# ●
# Feature
# scaling
# is
# essential
# for
# machine
# learning
# algorithms
# that
# calculate
# distances
# between
# data.
# If
# not
# scale,
# the
# feature
# with
# a
# higher
# value
# range
# starts
# dominating when calculating distances
# ●
# The
# machine
# learning
# algorithm
# works
# on
# numbers
# and
# does
# not
# know
# what
# that
# number represents
# ●
# Ex
# .
# A
# weight
# of
# 10
# grams
# and
# a
# price
# of
# 10
# dollars
# represents
# completely
# two
# different
# things
# —
# which
# is
# a
# no
# brainer
# for
# humans,
# but
# for
# a
# model
# as
# a
# feature,
# it treats both as same.
# Algorithms where feature scaling is required:

# %% [markdown]
# # 1.
# Distance-Based Algorithms:
# a.
# KNN
# b.
# K-means
# c.
# SVM

# %% [markdown]
# # 2.
# Gradient Descent Based Algorithms
# :
# a.
# Linear regression
# b.
# Logistic regression
# c.
# Neural Network

# %% [markdown]
# # 3.
# Principal Component Analysis(PCA).
# Algorithms where feature scaling is not required
# :

# %% [markdown]
# # 1.
# Tree Based Model:
# a.
# Decision Tree
# b.
# Random Forest
# c.
# AdaBoost

# %% [markdown]
# # 2.
# Linear Discriminant Analysis(LDA),

# %% [markdown]
# # 3.
# Naive Bayes Classifier
# Few key points to note:
# ●
# Scaling of variables does af fect the covariance matrix
# ●
# Do not apply scaling to the other One-Hot Encoded features

# %% [markdown]
# # 1.
# Normalization:
# Normalization is a scaling technique in which values are shifted and rescaled so
# that they end up ranging between 0 and

# %% [markdown]
# # 1. It is also known as Min-Max scaling.
# Xmax : Maximum value of the feature
# Xmin:Mnimum values of the feature.
# ●
# When the value of X is the minimum value in the column, the numerator will be 0,
# and hence Xnew is 0
# ●
# When the value of X is the maximum value in the column, the numerator is equal
# to the denominator and thus the value of Xnew is 1
# ●
# If the value of X is between the minimum and the maximum value, then the value
# of X’ is between 0 and 1
# When to use normalization:
# ●
# Normalization is good to use when you know that the distribution of your data
# does not follow a Gaussian distribution
# ●
# This can be useful in algorithms that do not assume any distribution of the data
# like K-Nearest Neighbors and Neural Networks
# ●
# Normalization is sensitive to outliers

# %% [markdown]
# # 2.
# Standardization:
# Standardization is scaling technique where the values
# are centered around the
# mean with a unit standard deviation. This means that the mean of the attribute becomes
# zero and the resultant distribution has a unit standard deviation
# .
# μ :
# Mean of the feature values
# σ :
# Standard Deviation
# When to use Standardization?
# ●
# Standardization, can be helpful in cases where the data follows a Gaussian
# distribution
# ●
# Normalization is sensitive to outliers
# Note:
# Choice of using normalization or standardization
# will depend on problem and the
# machine learning algorithm. There is no hard and fast rule to tell you when to normalize
# or standardize your data. You can always start by fitting your model to raw , normalized
# and standardized data and compare the performance for best results
