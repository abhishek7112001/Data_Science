# %% [markdown]
# # 1.
# What are Ensemble Methods in Machine Learning? What Are They and Why Use
# Them?

# %% [markdown]
# # 2.
# Explain the difference between bagging and boosting.

# %% [markdown]
# # 3.
# Why is Random Forest Algorithm popular?

# %% [markdown]
# # 4.
# Can Random Forest Algorithm be used both for Continuous and Categorical Target
# Variables?

# %% [markdown]
# # 5.
# What do you mean by Bagging?

# %% [markdown]
# # 6.
# Explain the working of the Random Forest Algorithm.

# %% [markdown]
# # 7.
# Why do we prefer a Forest (collection of Trees) rather than a single Tree?

# %% [markdown]
# # 8.
# What do you mean by Bootstrap Sample?

# %% [markdown]
# # 9.
# What does random refer to in ‘Random Forest’?

# %% [markdown]
# # 10.
# List down the features of Bagged Trees.

# %% [markdown]
# # 11.
# What are the Limitations of Bagging Trees?

# %% [markdown]
# # 12.
# Explain how the Random Forests give output for Classification, and Regression
# problems?

# %% [markdown]
# # 13.
# Does Random Forest need Pruning? Why or why not?

# %% [markdown]
# # 14.
# List down the hyper-parameters used to fine-tune the Random Forest.

# %% [markdown]
# # 15.
# What is the importance of max_feature hyperparameter?

# %% [markdown]
# # 16.
# What are the advantages and disadvantages of the Random Forest Algorithm?

# %% [markdown]
# # 17.
# What are the applications are random forests?

# %% [markdown]
# # 18.
# What are the Out-of-Bag samples?

# %% [markdown]
# # 19.
# What is Out-of-Bag Error?

# %% [markdown]
# # 20.
# How would you improve the performance of Random Forest?
