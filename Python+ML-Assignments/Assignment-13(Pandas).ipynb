# %% [markdown]
# # 1.
# Define the Pandas/Python pandas?

# %% [markdown]
# # 2.
# What are the different types of Data Structures in Pandas?

# %% [markdown]
# # 3.
# Explain Series and DataFrame In Pandas

# %% [markdown]
# # 4.
# How Can You Create An Empty DataFrame and series in Pandas?

# %% [markdown]
# # 5.
# How to check an empty DataFrame?

# %% [markdown]
# # 6.
# What Are The Most Important Features Of The Pandas Library?

# %% [markdown]
# # 7.
# How Will You Explain Reindexing In Pandas?

# %% [markdown]
# # 8.
# What
# are
# the
# different
# ways
# of
# creating
# DataFrame
# in
# pandas?
# Explain
# with
# examples.

# %% [markdown]
# # 9.
# Create a DataFrame using List.

# %% [markdown]
# # 10.
# Create a DataFrame using Numpy Functions.

# %% [markdown]
# # 11.
# How to convert a NumPy array to a DataFrame of a given shape?

# %% [markdown]
# # 12.
# Create a DataFrame using Dictionary with a list and arrays

# %% [markdown]
# # 13.
# How To Create A Copy Of The Series and DataFrame in Pandas?

# %% [markdown]
# # 14.
# How Will You Add An Index, Row, Or Column To A DataFrame In Pandas?

# %% [markdown]
# # 15.
# What
# Method
# Will
# You
# Use
# To
# Rename
# The
# Index
# Or
# Columns
# Of
# Pandas
# DataFrame?

# %% [markdown]
# # 16.
# How Can You Iterate Over DataFrame In Pandas?

# %% [markdown]
# # 17.
# How to create an array from DataFrame

# %% [markdown]
# # 18.
# How to create a list from DataFrame

# %% [markdown]
# # 19.
# How to Reset the dataframes index?

# %% [markdown]
# # 20.
# Write a Pandas program to count the number of rows and columns of a DataFrame

# %% [markdown]
# # 21.
# Write a Pandas program to add, subtract, multiple, and divide two Pandas Series

# %% [markdown]
# # 22.
# Write a Pandas program to import excel data into a Pandas dataframe

# %% [markdown]
# # 23.
# Write a Pandas program to read specific columns from a given excel file

# %% [markdown]
# # 24.
# Write a Pandas program to find the sum, mean, max, min value of

# %% [markdown]
# # 25.
# How Can A DataFrame Be Converted To An Excel File and CSV file?

# %% [markdown]
# # 26.
# What is Groupby Function In Pandas? Explain with example

# %% [markdown]
# # 27.
# What is the use of apply function in pandas?

# %% [markdown]
# # 28.
# How to use apply() with lambda function?

# %% [markdown]
# # 29.
# Explain is the use of info, describe, head, head, and tail functions

# %% [markdown]
# # 30.
# Write
# a
# Pandas
# program
# to
# check
# whether
# only
# a
# title
# case
# is
# present
# in
# a
# given
# column of a DataFrame.

# %% [markdown]
# # 31.
# What is the map Function In Pandas?

# %% [markdown]
# # 32.
# How will you add a column to a pandas DataFrame?

# %% [markdown]
# # 33.
# How will you add a column at a specific index to a pandas DataFrame?

# %% [markdown]
# # 34.
# How to Delete Indices, Rows, or Columns From a Pandas DataFrame?

# %% [markdown]
# # 35.
# How to get the items which are not common to both series A and series B?

# %% [markdown]
# # 36.
# How
# to
# get
# the
# minimum,
# 25th
# percentile,
# median,
# 75th,
# and
# max
# of
# a
# numeric
# series?

# %% [markdown]
# # 37.
# How can we sort the DataFrame?

# %% [markdown]
# # 38.
# How to drop duplicate rows from DataFrame?

# %% [markdown]
# # 39.
# How to drop duplicate columns from DataFrame?

# %% [markdown]
# # 40.
# Write
# a
# Pandas
# program
# to
# split
# a
# string
# of
# a
# column
# of
# a
# given
# DataFrame
# into
# multiple columns(Split Name and Surname)
