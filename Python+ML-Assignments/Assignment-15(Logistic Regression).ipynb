# %% [markdown]
# # 1.
# What
# is
# Data
# Science?
# List
# the
# differences
# between
# supervised
# and
# unsupervised
# learning.

# %% [markdown]
# # 2.
# What is logistic regression?

# %% [markdown]
# # 3.
# How will you deal with the multiclass classification problem using logistic regression?

# %% [markdown]
# # 4.
# Why is logistic regression very popular/widely used?

# %% [markdown]
# # 5.
# Why can’t linear regression be used instead of logistic regression for classification?

# %% [markdown]
# # 6.
# What is the formula for the logistic regression function?

# %% [markdown]
# # 7.
# What are the assumptions of logistic regression?

# %% [markdown]
# # 8.
# Why is logistic regression called regression and not classification?

# %% [markdown]
# # 9.
# Explain the general intuition behind logistic regression

# %% [markdown]
# # 10.
# Explain the significance of the sigmoid function.

# %% [markdown]
# # 11.
# How does Gradient Descent work in Logistic Regression?

# %% [markdown]
# # 12.
# What
# are
# outliers
# and
# how
# can
# the
# sigmoid
# function
# mitigate
# the
# problem
# of
# outliers
# in
# logistic regression?

# %% [markdown]
# # 13.
# What are the outputs of the logistic model and the logistic function?

# %% [markdown]
# # 14.
# Why can’t we use Mean Square Error (MSE) as a cost function for logistic regression?

# %% [markdown]
# # 15.
# What is the Confusion Matrix?

# %% [markdown]
# # 16.
# How do you define a classification report?

# %% [markdown]
# # 17.
# What are the false positives and false negatives?

# %% [markdown]
# # 18.
# What are the true positive rate (TPR) and false-positive rate (FPR)?

# %% [markdown]
# # 19.
# What is the false-positive rate (FPR) and false-negative rate (FNR)?

# %% [markdown]
# # 20.
# What are precision and recall? Explain the importance with examples?

# %% [markdown]
# # 21.
# What is the purpose of the precision-recall curve?

# %% [markdown]
# # 22.
# What is the f1 score and Explain its importance?

# %% [markdown]
# # 23.
# Write the equation and calculate the precision and recall rate.

# %% [markdown]
# # 24.
# How can you calculate accuracy using a confusion matrix?

# %% [markdown]
# # 25.
# What is sensitivity?

# %% [markdown]
# # 26.
# What is Specificity?

# %% [markdown]
# # 27.
# What is ROC Curve?

# %% [markdown]
# # 28.
# What is the importance of the ROC curve?

# %% [markdown]
# # 29.
# What are the advantages of ROC Curve?

# %% [markdown]
# # 30.
# What is Overfitting?

# %% [markdown]
# # 31.
# What is Underfitting?

# %% [markdown]
# # 32.
# What is Bias and Variance in Machine Learning?

# %% [markdown]
# # 33.
# What is the tradeoff between Bias and Variance?

# %% [markdown]
# # 34.
# Explain Bias and variance using the bulls-eye diagram

# %% [markdown]
# # 35.
# What is L1 and L2 regularization?

# %% [markdown]
# # 36.
# How do you find the best alpha for ridge regression?

# %% [markdown]
# # 37.
# Does scaling af fect logistic regression?
